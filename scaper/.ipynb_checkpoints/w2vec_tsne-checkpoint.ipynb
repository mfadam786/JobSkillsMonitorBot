# %%
import pandas as pd
from pathlib import Path
import unicodedata
import ast
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from gensim.models import Word2Vec
from nltk.corpus import stopwords

# %%
# nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
scraped_df = pd.read_csv("data/scraped.csv", comment="#")

# %%
def fix_content(x):
    
    if type(x) != type(np.nan):
      
        arr = []
        for i in ast.literal_eval(x):
            arr.append(unicodedata.normalize("NFKD", i).strip())
        return " ".join(np.asarray(arr).flatten().tolist())
scraped_df["fixed_content"] = scraped_df["main_content"].transform(fix_content)

# %%
scraped_df = scraped_df.dropna(subset=["fixed_content"])

# %%
scraped_df["sent_tokens"] = scraped_df["fixed_content"].transform(lambda x : sent_tokenize(x))

# %%
scraped_df["sent_tokens"][0][0]
# Out:
# 'MAHITAHI HAUORA  We are looking for an experienced Information Systems Facilitator who is comfortable in supporting internal and external customers across a range of platforms and programs and who has a flare for identifying and implementing improvement initiatives in IT functionality and systems that will enable enhanced quality, productivity, simplicity and efficiency for our users.'

# %%
sent_corp = [
]

stop_words = set(stopwords.words("english"))

for i in scraped_df["sent_tokens"].values:
    for sentence in i:
        
        sent = word_tokenize(sentence)
        sent_clean = []
        for word in sent:
            if word.isalpha() and word not in stop_words:
                sent_clean.append(word.lower())
       # word.lower() for word in sent if word.isalpha() and word not in stop_words
        sent_corp.append(sent_clean)

# %%
sent = ["sloth", "we", "an", "the","it", "i"]
for word in sent:
    print(word not in stop_words)
# Out:
# True
# False
# False
# False
# False
# False

# %%
def clean_corp(corp):
    for i in corp

# %%
len(sent)
# Out:
# 49532

# %%
model = Word2Vec(sent_corp, min_count=5,size=50,workers=12, iter=20, sg = 1)

# %%
model.wv.vocab.keys()
# Out:
# dict_keys(['hauora', 'we', 'looking', 'experienced', 'information', 'systems', 'facilitator', 'comfortable', 'supporting', 'internal', 'external', 'customers', 'across', 'range', 'platforms', 'programs', 'flare', 'identifying', 'implementing', 'improvement', 'initiatives', 'it', 'functionality', 'enable', 'enhanced', 'quality', 'productivity', 'simplicity', 'efficiency', 'users', 'about', 'primary', 'health', 'entity', 'te', 'charitable', 'social', 'enterprise', 'vision', 'everyone', 'equitable', 'opportunity', 'receive', 'care', 'wellbeing', 'support', 'need', 'way', 'works', 'centre', 'decisions', 'supports', 'healthcare', 'providers', 'including', 'general', 'practices', 'deliver', 'look', 'communities', 'also', 'directly', 'community', 'the', 'position', 'delivering', 'effective', 'timely', 'system', 'user', 'providing', 'realistic', 'solutions', 'improvements', 'working', 'collaboratively', 'ensure', 'organisational', 'daily', 'basis', 'infrastructure', 'planning', 'building', 'maintaining', 'relationships', 'this', 'role', 'plenty', 'variety', 'see', 'alongside', 'cio', 'members', 'team', 'enabling', 'organisation', 'work', 'fit', 'purpose', 'telecommunications', 'technology', 'applications', 'ease', 'use', 'to', 'considered', 'must', 'years', 'experience', 'proven', 'recent', 'is', 'processes', 'demonstrable', 'understanding', 'delivery', 'services', 'great', 'skills', 'ability', 'establish', 'priorities', 'meet', 'demands', 'deadlines', 'interpersonal', 'developing', 'constructive', 'sustainable', 'desirable', 'qualification', 'courses', 'an', 'advantage', 'would', 'sector', 'medtech', 'practice', 'management', 'a', 'detailed', 'description', 'application', 'employment', 'form', 'website', 'https', 'you', 'current', 'nz', 'visa', 'legal', 'right', 'if', 'passion', 'part', 'exciting', 'please', 'apply', 'forwarding', 'cover', 'letter', 'cv', 'hr', 'assistant', 'do', 'not', 'through', 'seek', 'only', 'received', 'by', 'following', 'above', 'instructions', 'close', 'monday', 'april', 'silverstripe', 'hunt', 'technical', 'director', 'join', 'professional', 'new', 'company', 'closely', 'directors', 'creative', 'complete', 'bespoke', 'leadership', 'report', 'head', 'client', 'strategy', 'responsible', 'oversight', 'direction', 'products', 'delivered', 'teams', 'ensuring', 'continued', 'adherence', 'best', 'your', 'expert', 'knowledge', 'allow', 'roadmap', 'business', 'unit', 'oversee', 'successful', 'outcome', 'introduced', 'actively', 'keep', 'tools', 'technologies', 'help', 'drive', 'existing', 'opportunities', 'innovation', 'significant', 'create', 'clients', 'zealand', 'as', 'provide', 'principal', 'developers', 'solution', 'architects', 'helping', 'identify', 'development', 'squads', 'key', 'staff', 'lead', 'product', 'architect', 'champion', 'sharing', 'offering', 'continues', 'grow', 'evolve', 'line', 'responsibilities', 'fantastic', 'who', 'player', 'knowledgeable', 'passionate', 'curious', 'enough', 'take', 'consider', 'people', 'ideas', 'suggestions', 'in', 'addition', 'have', 'advanced', 'cms', 'core', 'modules', 'php', 'javascript', 'strong', 'web', 'operations', 'cloud', 'computing', 'amazon', 'software', 'testing', 'design', 'implementation', 'methodology', 'capability', 'confident', 'areas', 'others', 'be', 'able', 'maintain', 'within', 'outside', 'understand', 'strategic', 'goals', 'set', 'objectives', 'align', 'readily', 'learn', 'adopt', 'exceptional', 'written', 'verbal', 'communication', 'effectively', 'communicate', 'concepts', 'additional', 'requirements', 'managing', 'individuals', 'perspective', 'vendor', 'digital', 'agency', 'commercial', 'environment', 'essential', 'how', 'all', 'submitted', 'visiting', 'channel', 'without', 'accepted', 'applicants', 'residency', 'valid', 'benefits', 'why', 'awesome', 'culture', 'want', 'excitement', 'intellectual', 'startup', 'sensible', 'model', 'big', 'trusting', 'using', 'solve', 'important', 'problems', 'reach', 'foster', 'values', 'honesty', 'comfort', 'adapta ...

# %%
model["workplace"]
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.5341224 ,  0.49985832, -0.03571999, -0.20064446,  0.82368416,
#         0.04411618, -0.31210986, -0.27457878, -0.4179791 , -0.2077065 ,
#         0.4189295 ,  0.21620058, -0.12934338,  0.5758715 ,  0.2749631 ,
#        -0.01766788, -0.7370485 , -0.6651483 ,  1.298259  ,  0.13757567,
#         0.09779014,  0.49045652, -0.53968096,  0.08905211, -0.7874192 ,
#        -0.22727613,  1.1210877 ,  0.39147523,  0.21361709, -0.4713037 ,
#         0.26674944,  0.15029971, -0.23824917, -0.488133  ,  0.34278893,
#        -0.3883541 , -0.7664061 , -0.09204368,  0.22024263,  0.28353876,
#        -0.33915257, -0.2621415 , -0.16756687, -0.39368382, -0.2755056 ,
#         0.41567877, -0.493251  , -0.09567542,  0.10107552, -0.20832585,
#        -0.80403596,  0.4200767 ,  0.33089736,  0.50307304,  0.53410226,
#        -0.2967939 ,  0.21965556,  0.00417999, -0.28654703, -0.07957685,
#        -0.1798094 ,  0.01959642, -0.65810615, -0.37191343, -0.00663324,
#        -0.37756404, -0.22619514, -0.35486537, -0.17721513,  0.2104134 ,
#         1.0399964 ,  0.02100774, -0.56163913, -0.56193584, -0.3024058 ,
#        -0.20922714,  0.6887362 , -0.10330408,  0.18118383,  0.23825143,
#         0.12470283, -0.22668202, -0.09952968,  0.76774704, -0.46107054,
#         0.3294482 ,  0.74033815,  0.11677928,  0.04492862, -0.30354914,
#        -0.35825428, -0.01629888,  0.22700125,  0.0268651 ,  0.04328261,
#        -0.03237957, -0.11662159,  0.79227996,  0.24323478, -0.14309742],
#       dtype=float32)

# %%
model["employer"]
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.3489579 ,  0.36741716, -0.57234263, -0.8606643 , -0.02431424,
#         0.9730563 ,  0.4283585 , -0.7923173 , -0.7245571 , -0.20828861,
#        -0.02349497,  0.59793293, -0.0889912 ,  0.24834391,  0.44033748,
#        -0.6360616 , -0.7347951 , -0.03486869,  0.7813875 ,  0.48382607,
#         0.37947425, -0.309462  , -0.03882295,  0.01102592, -0.6437603 ,
#         0.09806914,  1.0577258 ,  0.2883945 ,  0.917613  , -0.6357573 ,
#         0.4003202 , -0.20799018, -0.0149365 , -0.22947924, -0.01964587,
#        -0.25451562,  0.02769925,  0.22975047,  0.07100943,  0.25698978,
#         0.14620839, -0.76740694, -0.410307  , -0.06821334,  0.31340113,
#        -0.05940638, -0.2038397 ,  0.6629922 ,  0.16225809, -1.0090678 ,
#         0.05400539, -0.16034618, -0.01172217,  0.16199237, -0.31552958,
#         0.09354289,  0.29183677,  0.4814791 ,  0.24764746, -0.23019992,
#         0.10823817, -0.09123109, -1.2394596 ,  0.58377826,  0.27199325,
#        -0.32769793,  0.5938212 , -0.1503138 , -0.45117393,  0.7129892 ,
#         0.05370257, -0.68791974, -0.82331187, -0.49968117, -0.8115332 ,
#         0.1252121 , -0.25870124, -0.58800244,  0.01236202,  0.2054906 ,
#         0.12127589, -0.00387026,  0.01616476,  0.34103113,  0.18166155,
#         0.06170638, -0.09812855, -0.27065635,  0.02629503, -0.12104803,
#        -0.79519546, -0.18483126, -0.6393297 , -0.23052934,  0.391177  ,
#         0.19225615, -0.29200608,  0.21937081, -0.37537873, -0.56426626],
#       dtype=float32)

# %%
import sklearn
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
np.dot(model["employer"], model["workplace"])
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# 7.6716557

# %%
from sklearn.metrics.pairwise import cosine_similarity,cosine_distances

# %%
cosine_similarity(model["python"].reshape(1,-1), model["sql"].reshape(1,-1))
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([[0.68861735]], dtype=float32)

# %%
def display_closestwords_tsnescatterplot(model, word, size):
    
    arr = np.empty((0,size), dtype='f')
    word_labels = [word]
    close_words = model.similar_by_word(word)
    arr = np.append(arr, np.array([model[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
    tsne = TSNE(n_components=2, random_state=0)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)
    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    plt.scatter(x_coords, y_coords)
    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points')
        plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
        plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()
    
display_closestwords_tsnescatterplot(model, 'python', 100)
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
model.save("models/word2vec_uni.model")

# %%
model = Word2Vec.load("models/word2vec_sg.model")

# %%
model.wv

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
bigram = Phrases(sent_corp, min_count=5)

# %%
bigram.add_vocab(sent_corp)

# %%
bigram.export_phrases()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-7de5adaebb58> in <module>
# ----> 1 bigram.export_phrases()
#
# TypeError: export_phrases() missing 1 required positional argument: 'sentences'

# %%
bigrams =set(bigram.export_phrases(sent_corp))

# %%
list(bigrams)[:,:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-2f2bf61559c1> in <module>
# ----> 1 list(bigrams)[:,:1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
b_phraser = Phraser(bigram)

# %%
b_phraser.find_phrases()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-11f313e0906a> in <module>
# ----> 1 b_phraser.find_phrases()
#
# AttributeError: 'Phraser' object has no attribute 'find_phrases'

# %%
for sentence in sent_corp[:10]:
    print(bigram[sentence])
# Out:
# ['mahitahi_hauora', 'we', 'looking', 'experienced', 'information', 'systems', 'facilitator', 'comfortable', 'supporting', 'internal_external', 'customers', 'across', 'range', 'platforms', 'programs', 'flare', 'identifying', 'implementing', 'improvement', 'initiatives', 'it', 'functionality', 'systems', 'enable', 'enhanced', 'quality', 'productivity', 'simplicity', 'efficiency', 'users']
# ['about', 'mahitahi_hauora', 'mahitahi_hauora', 'primary', 'health', 'entity', 'te', 'tai', 'tokerau']
# ['it', 'charitable', 'social', 'enterprise', 'vision', 'everyone', 'tai', 'tokerau', 'equitable', 'opportunity', 'receive', 'care', 'wellbeing', 'support', 'need', 'way', 'works', 'centre', 'decisions', 'care', 'wellbeing']
# ['mahitahi_hauora', 'supports', 'primary', 'healthcare_providers', 'including', 'general', 'practices', 'health', 'providers', 'deliver', 'care', 'look', 'wellbeing', 'communities']
# ['we', 'also', 'deliver', 'care', 'wellbeing', 'support', 'directly', 'community']
# ['the', 'position', 'we', 'looking', 'information', 'systems', 'facilitator', 'experienced', 'delivering', 'effective', 'timely', 'it', 'support', 'internal_external', 'customers', 'identifying', 'system', 'user', 'deficiencies', 'providing', 'realistic', 'solutions', 'implementable', 'improvements', 'working', 'collaboratively', 'ensure', 'organisational', 'it', 'functionality', 'daily_basis', 'supporting', 'information', 'systems', 'infrastructure', 'planning', 'building_maintaining', 'relationships', 'this', 'role', 'plenty', 'variety', 'see', 'working', 'alongside', 'supporting', 'cio', 'members', 'information', 'systems', 'team', 'enabling', 'organisation', 'users', 'deliver', 'work', 'fit_purpose', 'information', 'systems', 'telecommunications', 'technology', 'applications', 'support', 'quality', 'efficiency', 'ease_use']
# ['to_considered', 'position', 'must', 'years', 'experience', 'information', 'systems', 'role', 'proven', 'recent', 'experience', 'supporting', 'internal', 'is', 'programs', 'processes', 'demonstrable', 'experience', 'understanding', 'information', 'systems', 'delivery', 'services', 'great', 'organisational', 'skills', 'ability', 'establish', 'priorities', 'meet_demands', 'deadlines', 'proven', 'interpersonal_skills', 'developing', 'constructive', 'sustainable', 'relationships', 'desirable', 'qualification', 'is', 'courses']
# ['an', 'advantage', 'would', 'understanding', 'primary', 'health_care', 'sector', 'medtech', 'practice', 'management', 'systems']
# ['a', 'detailed', 'position_description', 'application', 'employment', 'form', 'downloaded', 'website_https']
# ['you', 'must', 'current', 'nz', 'work', 'visa', 'legal_right', 'work', 'nz']

# %%
model = Word2Vec(bigram[sent_corp], min_count=5,size=50,workers=12, iter=20, sg = 1)

# %%
model["web developer"]
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-ad4effb7f864> in <module>
# ----> 1 model["web developer"]
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1459                     stacklevel=2
#    1460                 )
# -> 1461                 return func(*args, **kwargs)
#    1462
#    1463             return new_func1
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\word2vec.py in __getitem__(self, words)
#     930
#     931         """
# --> 932         return self.wv.__getitem__(words)
#     933
#     934     @deprecated("Method will be removed in 4.0.0, use self.wv.__contains__() instead")
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\keyedvectors.py in __getitem__(self, entities)
#     351         if isinstance(entities, string_types):
#     352             # allow calls like trained_model['office'], as a shorthand for trained_model[['office']]
# --> 353             return self.get_vector(entities)
#     354
#     355         return vstack([self.get_vector(entity) for entity in entities])
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, word)
#     469
#     470     def get_vector(self, word):
# --> 471         return self.word_vec(word)
#     472
#     473     def words_closer_than(self, w1, w2):
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'web developer' not in vocabulary"

# %%
model.wv.vocab.keys()
# Out:
# dict_keys(['we', 'looking', 'experienced', 'information', 'systems', 'facilitator', 'comfortable', 'supporting', 'internal_external', 'customers', 'across', 'range', 'platforms', 'programs', 'flare', 'identifying', 'implementing', 'improvement', 'initiatives', 'it', 'functionality', 'enable', 'enhanced', 'quality', 'productivity', 'simplicity', 'efficiency', 'users', 'about', 'primary', 'health', 'entity', 'te', 'charitable', 'social', 'enterprise', 'vision', 'everyone', 'equitable', 'opportunity', 'receive', 'care', 'wellbeing', 'support', 'need', 'way', 'works', 'centre', 'decisions', 'supports', 'healthcare_providers', 'including', 'general', 'practices', 'providers', 'deliver', 'look', 'communities', 'also', 'directly', 'community', 'the', 'position', 'delivering', 'effective', 'timely', 'system', 'user', 'providing', 'realistic', 'solutions', 'improvements', 'working', 'collaboratively', 'ensure', 'organisational', 'daily_basis', 'infrastructure', 'planning', 'building_maintaining', 'relationships', 'this', 'role', 'plenty', 'variety', 'see', 'alongside', 'cio', 'members', 'team', 'enabling', 'organisation', 'work', 'fit_purpose', 'telecommunications', 'technology', 'applications', 'to_considered', 'must', 'years', 'experience', 'proven', 'recent', 'internal', 'is', 'processes', 'demonstrable', 'understanding', 'delivery', 'services', 'great', 'skills', 'ability', 'establish', 'priorities', 'meet_demands', 'deadlines', 'interpersonal_skills', 'developing', 'constructive', 'sustainable', 'desirable', 'qualification', 'courses', 'an', 'advantage', 'would', 'health_care', 'sector', 'medtech', 'practice', 'management', 'a', 'detailed', 'position_description', 'application', 'employment', 'form', 'website_https', 'you', 'current', 'nz', 'visa', 'legal_right', 'if', 'passion', 'part', 'exciting', 'please_apply', 'forwarding', 'cover_letter', 'cv', 'hr', 'assistant', 'please', 'do', 'not', 'apply', 'through', 'seek', 'only', 'received', 'by', 'following', 'above', 'instructions', 'applications_close', 'silverstripe', 'hunt', 'technical', 'director', 'join', 'professional', 'new', 'company', 'closely', 'directors', 'creative', 'complete', 'bespoke', 'leadership', 'report_directly', 'head', 'client', 'strategy', 'responsible', 'oversight', 'direction', 'products', 'delivered', 'teams', 'ensuring', 'continued', 'adherence', 'best_practice', 'your', 'expert', 'knowledge', 'allow', 'roadmap', 'business', 'unit', 'oversee', 'successful', 'outcome', 'introduced', 'actively', 'keep', 'tools', 'technologies', 'help', 'drive', 'existing', 'opportunities', 'innovation', 'significant', 'create', 'clients', 'new_zealand', 'as', 'provide', 'principal', 'developers', 'solution_architects', 'helping', 'identify', 'development', 'squads', 'key', 'staff', 'lead', 'product', 'architect', 'champion', 'sharing', 'offering', 'continues_grow', 'evolve', 'line', 'responsibilities', 'fantastic', 'who', 'team_player', 'knowledgeable', 'passionate', 'curious', 'enough', 'take', 'consider', 'people', 'ideas', 'suggestions', 'in_addition', 'have', 'advanced', 'core', 'modules', 'php_javascript', 'strong', 'web', 'operations', 'cloud_computing', 'amazon_web', 'software', 'testing', 'design', 'implementation', 'best_practices', 'methodology', 'capability', 'confident', 'identifying_areas', 'others', 'be', 'able', 'create_maintain', 'within', 'outside', 'understand', 'strategic_goals', 'set', 'objectives', 'align', 'goals', 'readily', 'learn', 'adopt', 'exceptional', 'written_verbal', 'communication_skills', 'effectively_communicate', 'concepts', 'additional', 'requirements', 'managing', 'individuals', 'perspective', 'vendor', 'digital', 'agency', 'commercial', 'environment', 'essential', 'how_apply', 'all_applications', 'must_submitted', 'website', 'channel', 'without', 'cv_cover', 'letter', 'accepted', 'applicants', 'nz_residency', 'valid_nz', 'benefits', 'why', 'awesome', 'culture', 'want', 'excitement', 'startup', 'sensible', 'model', 'big', 'using', 'solv ...

# %%
model.wv.mostsim
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.19696486, -0.05325941, -0.30338755,  0.07169153, -0.7350428 ,
#         0.9576314 ,  0.13553649,  0.29655752, -0.36444855,  0.30395824,
#         0.01064511, -0.12758562,  0.39169842, -0.5168491 ,  0.49854153,
#         0.2553441 , -0.270386  , -0.4101954 , -0.33220464,  0.44603285,
#         0.83181375, -0.1394369 , -0.29905322,  0.04994597,  0.3579204 ,
#         0.4158099 ,  0.19681537, -0.09144596,  0.17675856,  0.3265174 ,
#         0.27181432,  0.3577468 ,  1.5926814 , -0.5778548 , -0.8989706 ,
#        -0.33955404, -0.40389666, -0.66158825, -0.05321743,  0.42556998,
#         0.33172345,  0.4424943 ,  0.43292987, -0.5092685 ,  0.47788417,
#         0.13257918, -0.4267839 , -0.35381103,  0.5864212 , -0.3157846 ],
#       dtype=float32)

# %%
 model.similar_by_word("attlassian")
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-4124d88dd901> in <module>
# ----> 1 model.similar_by_word("attlassian")
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1459                     stacklevel=2
#    1460                 )
# -> 1461                 return func(*args, **kwargs)
#    1462
#    1463             return new_func1
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\base_any2vec.py in similar_by_word(self, word, topn, restrict_vocab)
#    1409
#    1410         """
# -> 1411         return self.wv.similar_by_word(word, topn, restrict_vocab)
#    1412
#    1413     @deprecated("Method will be removed in 4.0.0, use self.wv.similar_by_vector() instead")
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\keyedvectors.py in similar_by_word(self, word, topn, restrict_vocab)
#     594
#     595         """
# --> 596         return self.most_similar(positive=[word], topn=topn, restrict_vocab=restrict_vocab)
#     597
#     598     def similar_by_vector(self, vector, topn=10, restrict_vocab=None):
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~\anaconda3\envs\scraper\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'attlassian' not in vocabulary"

# %%
model.save("models/word2vec_bi.model")

# %%
"_".join("asdf ffff".split(" "))
# Out:
# 'asdf_ffff'
