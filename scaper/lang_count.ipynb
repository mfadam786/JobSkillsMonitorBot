# %%
import pandas as pd
from pathlib import Path
import unicodedata
import ast
import numpy as np
import re

# %%
lang_df = pd.read_csv("data/fixed_langs.csv")

# %%
scraped_df = pd.read_csv("data/scraped.csv", comment="#")

# %%
count_df = pd.DataFrame()
count_df["lang"] = lang_df["fixed"]; count_df["count"] = 0

# %%
count_df
# Out:
#            lang  count
# 0        A.NET       0
# 1    A-0 System      0
# 2           A+       0
# 3          ABAP      0
# 4           ABC      0
# ..          ...    ...
# 680    ZetaLisp      0
# 681         Zig      0
# 682        ZOPL      0
# 683         ZPL      0
# 684         Z++      0
#
# [685 rows x 2 columns]

# %%
def fix_content(x):
    
    if type(x) != type(np.nan):
      
        arr = []
        for i in ast.literal_eval(x):
            arr.append(unicodedata.normalize("NFKD", i).strip())
        return " ".join(np.asarray(arr).flatten().tolist())
scraped_df["fixed_content"] = scraped_df["main_content"].transform(fix_content)

# %%
scraped_df = scraped_df.dropna(subset=["fixed_content"])

# %%
scraped_df["fixed_content"][0]
# Out:
# 'MAHITAHI HAUORA  We are looking for an experienced Information Systems Facilitator who is comfortable in supporting internal and external customers across a range of platforms and programs and who has a flare for identifying and implementing improvement initiatives in IT functionality and systems that will enable enhanced quality, productivity, simplicity and efficiency for our users.  About Mahitahi Hauora  Mahitahi Hauora is the primary health entity for Te Tai Tokerau. It is a charitable social enterprise with a vision for everyone in Tai Tokerau to have an equitable opportunity to receive the care and wellbeing support they need, in the way that works for them, and to be at the centre of decisions about their care and wellbeing.  Mahitahi Hauora supports Primary Healthcare providers including General Practices and Māori Health Providers to deliver care and to look after the wellbeing of their communities and whānau. We also deliver care and wellbeing support directly to the community and whānau.  The Position  We are looking for an Information Systems Facilitator who is experienced in:   Delivering effective and timely IT support to Internal and External customers  Identifying system and user deficiencies and providing realistic solutions and implementable improvements  Working collaboratively to ensure organisational IT functionality on a daily basis  Supporting with Information Systems infrastructure and planning  Building and maintaining relationships  This role has plenty of variety and will see you working alongside and supporting the CIO and other members of the Information Systems team in enabling the organisation’s users to deliver their work through fit for purpose information systems, telecommunications technology, and applications that support quality, efficiency, and ease of use.  To be considered for this position you must have:   5 years’ experience in an Information Systems role  Proven and recent experience in supporting internal IS programs and processes  Demonstrable experience in understanding of Information systems and delivery of services  Great organisational skills and an ability to establish priorities and meet demands and deadlines  Proven interpersonal skills in developing constructive and sustainable relationships  Desirable is a qualification or IS courses.  An advantage would be an understanding of the primary health care sector and Medtech practice management systems.  A detailed position description and Application for Employment form can be downloaded from our website https://www.mahitahihauora.co.nz/vacancies/Mahitahi-Hauora-PHE-Information-Systems-Facilitator.  You must have a current NZ work visa and the legal right to work in NZ.  If you have the skills for this role and passion to be part of this exciting team, please apply by forwarding your cover letter, CV and Application for Employment Form to HR Assistant at hr@mahitahihauora.co.nz .  PLEASE DO NOT APPLY THROUGH SEEK.  APPLICATIONS ONLY RECEIVED BY FOLLOWING THE ABOVE INSTRUCTIONS.  Applications Close: Monday 5th April 2021'

# %%
for i in count_df.index:
    lang = count_df["lang"].loc[i].lower()
    for j in all_strings:
        if j:
            if lang in j.lower():
                count_df["count"].loc[i] += 1
# Out:
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
count_df.index
# Out:
# RangeIndex(start=0, stop=685, step=1)

# %%
print(count_df["lang"].loc[0].lower())
# Out:
# a.net

# %%
count_df.to_csv("data/lang_count.csv")

# %%
txt = scraped_df["fixed_content"][1]

# %%
re.search(exp, txt, re.IGNORECASE)
# Out:
# <re.Match object; span=(1981, 1986), match='/CSS '>

# %%
import re

# %%
exp = r"(/|\s)css([,/]|\s)"

# %%
content = scraped_df["fixed_content"].values
for i in count_df.index:
   # lang = "".join(list(map(lambda o: r"\\" +o , list(count_df["lang"].loc[i].strip()))))
    lang = re.escape(count_df["lang"].loc[i].strip())         
    exp = r"(/|\s)"+lang+r"([,/]|\s)"
   # print(exp)
    for j in content:
        if re.search(exp, j, re.IGNORECASE):
            count_df["count"].loc[i] += 1
#     if i > 5:
#         break

# %%
scraped_df["job_subsection"].unique()

# %%
sub_count_df

# %%
subs = scraped_df["job_subsection"].unique()

for sub in subs:
    sub_df = scraped_df.loc[scraped_df["job_subsection"] == sub]
    content = sub_df["fixed_content"].values
    sub_count_df = pd.DataFrame()
    sub_count_df["lang"] = lang_df["fixed"]; sub_count_df["count"] = 0
    for i in sub_count_df.index:
        # lang = "".join(list(map(lambda o: r"\\" +o , list(count_df["lang"].loc[i].strip()))))
        lang = re.escape(sub_count_df["lang"].loc[i].strip())         
        exp = r"(/|\s)"+lang+r"([,/]|\s)"
        print(exp)
        for j in content:
            if re.search(exp, j, re.IGNORECASE):
                sub_count_df["count"].loc[i] += 1
    sub_count_df.to_csv(f"data/subsections/{sub}_lang_count.csv")

# %%
exp

# %%
lang

# %%
count_df.index

# %%
count_df

# %%
lang = "".join(list(map(lambda o: "\\"+o , list(count_df["lang"].loc[i].strip())))

# %%
lang

# %%
list(count_df["lang"].loc[0].strip())

# %%
exp[8]

# %%
exp

# %%
lang

# %%
list(lang)

# %%
content = scraped_df["fixed_content"].values
for i in count_df.index:
   # lang = "".join(list(map(lambda o: r"\\" +o , list(count_df["lang"].loc[i].strip()))))
    lang = re.escape(count_df["lang"].loc[i].strip())         
    exp = r"(/|\s)"+lang+r"([,/]|\s)"
   # print(exp)
    for j in content:
        if re.search(exp, j, re.IGNORECASE):
            count_df["count"].loc[i] += 1
#     if i > 5:
#         break
# Out:
# (/|\s)A\.NET([,/]|\s)
# (/|\s)A\-0\ System([,/]|\s)
# (/|\s)A\+([,/]|\s)
# (/|\s)ABAP([,/]|\s)
# (/|\s)ABC([,/]|\s)
# (/|\s)ABC\ ALGOL([,/]|\s)
# (/|\s)ACC([,/]|\s)
# (/|\s)Accent([,/]|\s)
# (/|\s)Ace\ DASL([,/]|\s)
# (/|\s)Action!([,/]|\s)
# (/|\s)ActionScript([,/]|\s)
# (/|\s)Actor([,/]|\s)
# (/|\s)Ada([,/]|\s)
# (/|\s)Adenine([,/]|\s)
# (/|\s)AdvPL([,/]|\s)
# (/|\s)Agda([,/]|\s)
# (/|\s)Agilent\ VEE([,/]|\s)
# (/|\s)Agora([,/]|\s)
# (/|\s)AIMMS([,/]|\s)
# (/|\s)Aldor([,/]|\s)
# (/|\s)Alef([,/]|\s)
# (/|\s)ALF([,/]|\s)
# (/|\s)ALGOL\ 58([,/]|\s)
# (/|\s)ALGOL\ 60([,/]|\s)
# (/|\s)ALGOL\ 68([,/]|\s)
# (/|\s)ALGOL\ W([,/]|\s)
# (/|\s)Alice([,/]|\s)
# (/|\s)Alma\-0([,/]|\s)
# (/|\s)AmbientTalk([,/]|\s)
# (/|\s)Amiga\ E([,/]|\s)
# (/|\s)AMOS([,/]|\s)
# (/|\s)AMPL([,/]|\s)
# (/|\s)AngelScript([,/]|\s)
# (/|\s)Apache\ Pig\ latin([,/]|\s)
# (/|\s)Apex([,/]|\s)
# (/|\s)APL([,/]|\s)
# (/|\s)App\ Inventor\ for\ Android's\ visual\ block\ language([,/]|\s)
# (/|\s)AppleScript([,/]|\s)
# (/|\s)APT([,/]|\s)
# (/|\s)Arc([,/]|\s)
# (/|\s)ARexx([,/]|\s)
# (/|\s)Argus([,/]|\s)
# (/|\s)Assembly\ language([,/]|\s)
# (/|\s)AutoIt([,/]|\s)
# (/|\s)AutoLISP\ /\ Visual\ LISP([,/]|\s)
# (/|\s)Averest([,/]|\s)
# (/|\s)AWK([,/]|\s)
# (/|\s)Axum([,/]|\s)
# (/|\s)B([,/]|\s)
# (/|\s)Babbage([,/]|\s)
# (/|\s)Ballerina([,/]|\s)
# (/|\s)Bash([,/]|\s)
# (/|\s)BASIC([,/]|\s)
# (/|\s)Batch\ file([,/]|\s)
# (/|\s)bc([,/]|\s)
# (/|\s)BCPL([,/]|\s)
# (/|\s)BeanShell([,/]|\s)
# (/|\s)Bertrand([,/]|\s)
# (/|\s)BETA([,/]|\s)
# (/|\s)BLISS([,/]|\s)
# (/|\s)Blockly([,/]|\s)
# (/|\s)BlooP([,/]|\s)
# (/|\s)Boo([,/]|\s)
# (/|\s)Boomerang([,/]|\s)
# (/|\s)Bosque([,/]|\s)
# (/|\s)C\ –\ ISO/IEC\ 9899([,/]|\s)
# (/|\s)C\-\-([,/]|\s)
# (/|\s)C\+\+([,/]|\s)
# (/|\s)C\*([,/]|\s)
# (/|\s)C\#([,/]|\s)
# (/|\s)C/AL([,/]|\s)
# (/|\s)Caché\ ObjectScript([,/]|\s)
# (/|\s)C\ Shell([,/]|\s)
# (/|\s)Caml([,/]|\s)
# (/|\s)Cayenne([,/]|\s)
# (/|\s)CDuce([,/]|\s)
# (/|\s)Cecil([,/]|\s)
# (/|\s)Cesil([,/]|\s)
# (/|\s)Céu([,/]|\s)
# (/|\s)Ceylon([,/]|\s)
# (/|\s)CFEngine([,/]|\s)
# (/|\s)Cg([,/]|\s)
# (/|\s)Ch([,/]|\s)
# (/|\s)Chapel([,/]|\s)
# (/|\s)Charm([,/]|\s)
# (/|\s)CHILL([,/]|\s)
# (/|\s)CHIP\-8([,/]|\s)
# (/|\s)ChucK([,/]|\s)
# (/|\s)Cilk([,/]|\s)
# (/|\s)CL([,/]|\s)
# (/|\s)Claire([,/]|\s)
# (/|\s)Clarion([,/]|\s)
# (/|\s)Clean([,/]|\s)
# (/|\s)Clipper([,/]|\s)
# (/|\s)CLIPS([,/]|\s)
# (/|\s)CLIST([,/]|\s)
# (/|\s)Clojure([,/]|\s)
# (/|\s)CLU([,/]|\s)
# (/|\s)CMS\-2([,/]|\s)
# (/|\s)COBOL\ –\ ISO/IEC\ 1989([,/]|\s)
# (/|\s)CobolScript\ –\ COBOL\ Scripting\ language([,/]|\s)
# (/|\s)Cobra([,/]|\s)
# (/|\s)CoffeeScript([,/]|\s)
# (/|\s)ColdFusion([,/]|\s)
# (/|\s)COMAL([,/]|\s)
# (/|\s)Combined\ Programming\ Language([,/]|\s)
# (/|\s)COMIT([,/]|\s)
# (/|\s)Common\ Intermediate\ Language([,/]|\s)
# (/|\s)Common\ Lisp([,/]|\s)
# (/|\s)COMPASS([,/]|\s)
# (/|\s)Component\ Pascal([,/]|\s)
# (/|\s)Constraint\ Handling\ Rules([,/]|\s)
# (/|\s)COMTRAN([,/]|\s)
# (/|\s)Cool([,/]|\s)
# (/|\s)Coq([,/]|\s)
# (/|\s)Coral\ 66([,/]|\s)
# (/|\s)CorVision([,/]|\s)
# (/|\s)COWSEL([,/]|\s)
# (/|\s)CPL([,/]|\s)
# (/|\s)Cryptol([,/]|\s)
# (/|\s)Crystal([,/]|\s)
# (/|\s)Csound([,/]|\s)
# (/|\s)Cuneiform([,/]|\s)
# (/|\s)Curl([,/]|\s)
# (/|\s)Curry([,/]|\s)
# (/|\s)Cybil([,/]|\s)
# (/|\s)Cyclone([,/]|\s)
# (/|\s)Cypher\ Query\ Language([,/]|\s)
# (/|\s)Cython([,/]|\s)
# (/|\s)CEEMAC([,/]|\s)
# (/|\s)D([,/]|\s)
# (/|\s)Dart([,/]|\s)
# (/|\s)Darwin([,/]|\s)
# (/|\s)DataFlex([,/]|\s)
# (/|\s)Datalog([,/]|\s)
# (/|\s)DATATRIEVE([,/]|\s)
# (/|\s)dBase([,/]|\s)
# (/|\s)dc([,/]|\s)
# (/|\s)DCL([,/]|\s)
# (/|\s)Delphi([,/]|\s)
# (/|\s)DinkC([,/]|\s)
# (/|\s)DIBOL([,/]|\s)
# (/|\s)Dog([,/]|\s)
# (/|\s)Draco([,/]|\s)
# (/|\s)DRAKON([,/]|\s)
# (/|\s)Dylan([,/]|\s)
# (/|\s)DYNAMO([,/]|\s)
# (/|\s)DAX([,/]|\s)
# (/|\s)E([,/]|\s)
# (/|\s)Ease([,/]|\s)
# (/|\s)Easy\ PL/I([,/]|\s)
# (/|\s)EASYTRIEVE\ PLUS([,/]|\s)
# (/|\s)eC([,/]|\s)
# (/|\s)ECMAScript([,/]|\s)
# (/|\s)Edinburgh\ IMP([,/]|\s)
# (/|\s)EGL([,/]|\s)
# (/|\s)Eiffel([,/]|\s)
# (/|\s)ELAN([,/]|\s)
# (/|\s)Elixir([,/]|\s)
# (/|\s)Elm([,/]|\s)
# (/|\s)Emacs\ Lisp([,/]|\s)
# (/|\s)Emerald([,/]|\s)
# (/|\s)Epigram([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)Erlang([,/]|\s)
# (/|\s)es([,/]|\s)
# (/|\s)Escher([,/]|\s)
# (/|\s)ESPOL([,/]|\s)
# (/|\s)Esterel([,/]|\s)
# (/|\s)Etoys([,/]|\s)
# (/|\s)Euclid([,/]|\s)
# (/|\s)Euler([,/]|\s)
# (/|\s)Euphoria([,/]|\s)
# (/|\s)EusLisp\ Robot\ Programming\ Language([,/]|\s)
# (/|\s)CMS\ EXEC([,/]|\s)
# (/|\s)EXEC\ 2([,/]|\s)
# (/|\s)Executable\ UML([,/]|\s)
# (/|\s)Ezhil([,/]|\s)
# (/|\s)F([,/]|\s)
# (/|\s)F\#([,/]|\s)
# (/|\s)F\*([,/]|\s)
# (/|\s)Factor([,/]|\s)
# (/|\s)Fantom([,/]|\s)
# (/|\s)FAUST([,/]|\s)
# (/|\s)FFP([,/]|\s)
# (/|\s)fish([,/]|\s)
# (/|\s)Fjölnir([,/]|\s)
# (/|\s)FL([,/]|\s)
# (/|\s)Flavors([,/]|\s)
# (/|\s)Flex([,/]|\s)
# (/|\s)Flix([,/]|\s)
# (/|\s)FlooP([,/]|\s)
# (/|\s)FLOW\-MASTIC([,/]|\s)
# (/|\s)FOCAL([,/]|\s)
# (/|\s)FOCUS([,/]|\s)
# (/|\s)FOIL([,/]|\s)
# (/|\s)FORMAC([,/]|\s)
# (/|\s)@Formula([,/]|\s)
# (/|\s)Forth([,/]|\s)
# (/|\s)Fortran\ –\ ISO/IEC\ 1539([,/]|\s)
# (/|\s)Fortress([,/]|\s)
# (/|\s)FP([,/]|\s)
# (/|\s)Franz\ Lisp([,/]|\s)
# (/|\s)Futhark([,/]|\s)
# (/|\s)F\-Script([,/]|\s)
# (/|\s)Game\ Maker\ Language([,/]|\s)
# (/|\s)GameMonkey\ Script([,/]|\s)
# (/|\s)GAMS([,/]|\s)
# (/|\s)GAP([,/]|\s)
# (/|\s)G\-code([,/]|\s)
# (/|\s)GDScript([,/]|\s)
# (/|\s)Genie([,/]|\s)
# (/|\s)GDL([,/]|\s)
# (/|\s)GEORGE([,/]|\s)
# (/|\s)GLSL([,/]|\s)
# (/|\s)GNU\ E([,/]|\s)
# (/|\s)GNU\ Guile([,/]|\s)
# (/|\s)Go([,/]|\s)
# (/|\s)Go!([,/]|\s)
# (/|\s)GOAL([,/]|\s)
# (/|\s)Gödel([,/]|\s)
# (/|\s)Golo([,/]|\s)
# (/|\s)GOM([,/]|\s)
# (/|\s)Google\ Apps\ Script([,/]|\s)
# (/|\s)Gosu([,/]|\s)
# (/|\s)GOTRAN([,/]|\s)
# (/|\s)GPSS([,/]|\s)
# (/|\s)GraphTalk([,/]|\s)
# (/|\s)GRASS([,/]|\s)
# (/|\s)Grasshopper([,/]|\s)
# (/|\s)Groovy([,/]|\s)
# (/|\s)Hack([,/]|\s)
# (/|\s)HAGGIS([,/]|\s)
# (/|\s)HAL/S([,/]|\s)
# (/|\s)Halide([,/]|\s)
# (/|\s)Hamilton\ C\ shell([,/]|\s)
# (/|\s)Harbour([,/]|\s)
# (/|\s)Hartmann\ pipelines([,/]|\s)
# (/|\s)Haskell([,/]|\s)
# (/|\s)Haxe([,/]|\s)
# (/|\s)Hermes([,/]|\s)
# (/|\s)High\ Level\ Assembly([,/]|\s)
# (/|\s)HLSL([,/]|\s)
# (/|\s)Hollywood([,/]|\s)
# (/|\s)HolyC([,/]|\s)
# (/|\s)Hop([,/]|\s)
# (/|\s)Hopscotch([,/]|\s)
# (/|\s)Hope([,/]|\s)
# (/|\s)Hugo([,/]|\s)
# (/|\s)Hume([,/]|\s)
# (/|\s)HyperTalk([,/]|\s)
# (/|\s)Io([,/]|\s)
# (/|\s)Icon([,/]|\s)
# (/|\s)IBM\ Basic\ assembly\ language([,/]|\s)
# (/|\s)IBM\ HAScript([,/]|\s)
# (/|\s)IBM\ Informix\-4GL([,/]|\s)
# (/|\s)IBM\ RPG([,/]|\s)
# (/|\s)IDL([,/]|\s)
# (/|\s)Idris([,/]|\s)
# (/|\s)Inform([,/]|\s)
# (/|\s)J([,/]|\s)
# (/|\s)J\#([,/]|\s)
# (/|\s)J\+\+([,/]|\s)
# (/|\s)JADE([,/]|\s)
# (/|\s)Jai([,/]|\s)
# (/|\s)JAL([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)JASS([,/]|\s)
# (/|\s)Java([,/]|\s)
# (/|\s)JavaFX\ Script([,/]|\s)
# (/|\s)JavaScript([,/]|\s)
# (/|\s)Jess([,/]|\s)
# (/|\s)JCL([,/]|\s)
# (/|\s)JEAN([,/]|\s)
# (/|\s)Join\ Java([,/]|\s)
# (/|\s)JOSS([,/]|\s)
# (/|\s)Joule([,/]|\s)
# (/|\s)JOVIAL([,/]|\s)
# (/|\s)Joy([,/]|\s)
# (/|\s)JScript([,/]|\s)
# (/|\s)JScript\ \.NET([,/]|\s)
# (/|\s)Julia([,/]|\s)
# (/|\s)Jython([,/]|\s)
# (/|\s)K([,/]|\s)
# (/|\s)Kaleidoscope([,/]|\s)
# (/|\s)Karel([,/]|\s)
# (/|\s)KEE([,/]|\s)
# (/|\s)Kixtart([,/]|\s)
# (/|\s)Klerer\-May\ System([,/]|\s)
# (/|\s)KIF([,/]|\s)
# (/|\s)Kojo([,/]|\s)
# (/|\s)Kotlin([,/]|\s)
# (/|\s)KRC([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRYPTON([,/]|\s)
# (/|\s)KornShell([,/]|\s)
# (/|\s)Kodu([,/]|\s)
# (/|\s)Kv([,/]|\s)
# (/|\s)LabVIEW([,/]|\s)
# (/|\s)Ladder([,/]|\s)
# (/|\s)LANSA([,/]|\s)
# (/|\s)Lasso([,/]|\s)
# (/|\s)Lava([,/]|\s)
# (/|\s)LC\-3([,/]|\s)
# (/|\s)Lean([,/]|\s)
# (/|\s)Legoscript([,/]|\s)
# (/|\s)LIL([,/]|\s)
# (/|\s)LilyPond([,/]|\s)
# (/|\s)Limbo([,/]|\s)
# (/|\s)Limnor([,/]|\s)
# (/|\s)LINC([,/]|\s)
# (/|\s)Lingo([,/]|\s)
# (/|\s)LINQ([,/]|\s)
# (/|\s)LIS([,/]|\s)
# (/|\s)LISA([,/]|\s)
# (/|\s)Language\ H([,/]|\s)
# (/|\s)Lisp\ –\ ISO/IEC\ 13816([,/]|\s)
# (/|\s)Lite\-C([,/]|\s)
# (/|\s)Lithe([,/]|\s)
# (/|\s)Little\ b([,/]|\s)
# (/|\s)LLL([,/]|\s)
# (/|\s)Logo([,/]|\s)
# (/|\s)Logtalk([,/]|\s)
# (/|\s)LotusScript([,/]|\s)
# (/|\s)LPC([,/]|\s)
# (/|\s)LSE([,/]|\s)
# (/|\s)LSL([,/]|\s)
# (/|\s)LiveCode([,/]|\s)
# (/|\s)LiveScript([,/]|\s)
# (/|\s)Lua([,/]|\s)
# (/|\s)Lucid([,/]|\s)
# (/|\s)Lustre([,/]|\s)
# (/|\s)LYaPAS([,/]|\s)
# (/|\s)Lynx([,/]|\s)
# (/|\s)M2001([,/]|\s)
# (/|\s)M4([,/]|\s)
# (/|\s)M\#([,/]|\s)
# (/|\s)Machine\ code([,/]|\s)
# (/|\s)MAD([,/]|\s)
# (/|\s)MAD/I([,/]|\s)
# (/|\s)Magik([,/]|\s)
# (/|\s)Magma([,/]|\s)
# (/|\s)Máni([,/]|\s)
# (/|\s)Maple([,/]|\s)
# (/|\s)MAPPER([,/]|\s)
# (/|\s)MARK\-IV([,/]|\s)
# (/|\s)Mary([,/]|\s)
# (/|\s)MATLAB([,/]|\s)
# (/|\s)MASM\ Microsoft\ Assembly\ x86([,/]|\s)
# (/|\s)MATH\-MATIC([,/]|\s)
# (/|\s)Maude\ system([,/]|\s)
# (/|\s)Maxima([,/]|\s)
# (/|\s)Max([,/]|\s)
# (/|\s)MaxScript\ internal\ language\ 3D\ Studio\ Max([,/]|\s)
# (/|\s)Maya([,/]|\s)
# (/|\s)MDL([,/]|\s)
# (/|\s)Mercury([,/]|\s)
# (/|\s)Mesa([,/]|\s)
# (/|\s)MHEG\-5([,/]|\s)
# (/|\s)Microcode([,/]|\s)
# (/|\s)MicroScript([,/]|\s)
# (/|\s)Microsoft\ Power\ Fx([,/]|\s)
# (/|\s)MIIS([,/]|\s)
# (/|\s)Milk([,/]|\s)
# (/|\s)MIMIC([,/]|\s)
# (/|\s)Mirah([,/]|\s)
# (/|\s)Miranda([,/]|\s)
# (/|\s)MIVA\ Script([,/]|\s)
# (/|\s)ML([,/]|\s)
# (/|\s)Model\ 204([,/]|\s)
# (/|\s)Modelica([,/]|\s)
# (/|\s)Modula([,/]|\s)
# (/|\s)Modula\-2([,/]|\s)
# (/|\s)Modula\-3([,/]|\s)
# (/|\s)Mohol([,/]|\s)
# (/|\s)MOO([,/]|\s)
# (/|\s)Mortran([,/]|\s)
# (/|\s)Mouse([,/]|\s)
# (/|\s)MPD([,/]|\s)
# (/|\s)MSL([,/]|\s)
# (/|\s)MUMPS([,/]|\s)
# (/|\s)MuPAD([,/]|\s)
# (/|\s)Mutan([,/]|\s)
# (/|\s)Mystic\ Programming\ Language([,/]|\s)
# (/|\s)NASM([,/]|\s)
# (/|\s)Napier88([,/]|\s)
# (/|\s)Neko([,/]|\s)
# (/|\s)Nemerle([,/]|\s)
# (/|\s)NESL([,/]|\s)
# (/|\s)Net\.Data([,/]|\s)
# (/|\s)NetLogo([,/]|\s)
# (/|\s)NetRexx([,/]|\s)
# (/|\s)NewLISP([,/]|\s)
# (/|\s)NEWP([,/]|\s)
# (/|\s)Newspeak([,/]|\s)
# (/|\s)NewtonScript([,/]|\s)
# (/|\s)Nial([,/]|\s)
# (/|\s)Nickle([,/]|\s)
# (/|\s)Nim([,/]|\s)
# (/|\s)Nix([,/]|\s)
# (/|\s)NPL([,/]|\s)
# (/|\s)Not\ eXactly\ C([,/]|\s)
# (/|\s)Not\ Quite\ C([,/]|\s)
# (/|\s)NSIS([,/]|\s)
# (/|\s)Nu([,/]|\s)
# (/|\s)NWScript([,/]|\s)
# (/|\s)NXT\-G([,/]|\s)
# (/|\s)o:XML([,/]|\s)
# (/|\s)Oak([,/]|\s)
# (/|\s)Oberon([,/]|\s)
# (/|\s)OBJ2([,/]|\s)
# (/|\s)Object\ Lisp([,/]|\s)
# (/|\s)ObjectLOGO([,/]|\s)
# (/|\s)Object\ REXX([,/]|\s)
# (/|\s)Object\ Pascal([,/]|\s)
# (/|\s)Objective\-C([,/]|\s)
# (/|\s)Objective\-J([,/]|\s)
# (/|\s)Obliq([,/]|\s)
# (/|\s)OCaml([,/]|\s)
# (/|\s)occam([,/]|\s)
# (/|\s)occam\-π([,/]|\s)
# (/|\s)Octave([,/]|\s)
# (/|\s)OmniMark([,/]|\s)
# (/|\s)Opa([,/]|\s)
# (/|\s)Opal([,/]|\s)
# (/|\s)OpenCL([,/]|\s)
# (/|\s)OpenEdge\ ABL([,/]|\s)
# (/|\s)OPL([,/]|\s)
# (/|\s)OpenVera([,/]|\s)
# (/|\s)OPS5([,/]|\s)
# (/|\s)OptimJ([,/]|\s)
# (/|\s)Orc([,/]|\s)
# (/|\s)ORCA/Modula\-2([,/]|\s)
# (/|\s)Oriel([,/]|\s)
# (/|\s)Orwell([,/]|\s)
# (/|\s)Oxygene([,/]|\s)
# (/|\s)Oz([,/]|\s)
# (/|\s)P([,/]|\s)
# (/|\s)P4([,/]|\s)
# (/|\s)P′′([,/]|\s)
# (/|\s)ParaSail([,/]|\s)
# (/|\s)PARI/GP([,/]|\s)
# (/|\s)Pascal\ –\ ISO\ 7185([,/]|\s)
# (/|\s)Pascal\ Script([,/]|\s)
# (/|\s)PCASTL([,/]|\s)
# (/|\s)PCF([,/]|\s)
# (/|\s)PEARL([,/]|\s)
# (/|\s)PeopleCode([,/]|\s)
# (/|\s)Perl([,/]|\s)
# (/|\s)PDL([,/]|\s)
# (/|\s)Pharo([,/]|\s)
# (/|\s)PHP([,/]|\s)
# (/|\s)Pico([,/]|\s)
# (/|\s)Picolisp([,/]|\s)
# (/|\s)Pict([,/]|\s)
# (/|\s)Pike([,/]|\s)
# (/|\s)PILOT([,/]|\s)
# (/|\s)Pipelines([,/]|\s)
# (/|\s)Pizza([,/]|\s)
# (/|\s)PL\-11([,/]|\s)
# (/|\s)PL/0([,/]|\s)
# (/|\s)PL/B([,/]|\s)
# (/|\s)PL/C([,/]|\s)
# (/|\s)PL/I\ –\ ISO\ 6160([,/]|\s)
# (/|\s)PL/M([,/]|\s)
# (/|\s)PL/P([,/]|\s)
# (/|\s)PL/SQL([,/]|\s)
# (/|\s)PL360([,/]|\s)
# (/|\s)PLANC([,/]|\s)
# (/|\s)Plankalkül([,/]|\s)
# (/|\s)Planner([,/]|\s)
# (/|\s)PLEX([,/]|\s)
# (/|\s)PLEXIL([,/]|\s)
# (/|\s)Plus([,/]|\s)
# (/|\s)POP\-11([,/]|\s)
# (/|\s)POP\-2([,/]|\s)
# (/|\s)PostScript([,/]|\s)
# (/|\s)PortablE([,/]|\s)
# (/|\s)POV\-Ray\ SDL([,/]|\s)
# (/|\s)Powerhouse([,/]|\s)
# (/|\s)PowerBuilder\ –\ 4GL\ GUI\ application\ generator\ from\ Sybase([,/]|\s)
# (/|\s)PowerShell([,/]|\s)
# (/|\s)PPL([,/]|\s)
# (/|\s)Processing([,/]|\s)
# (/|\s)Processing\.js([,/]|\s)
# (/|\s)Prograph([,/]|\s)
# (/|\s)PROIV([,/]|\s)
# (/|\s)Project\ Verona([,/]|\s)
# (/|\s)Prolog([,/]|\s)
# (/|\s)PROMAL([,/]|\s)
# (/|\s)Promela([,/]|\s)
# (/|\s)PROSE\ modeling\ language([,/]|\s)
# (/|\s)PROTEL([,/]|\s)
# (/|\s)ProvideX([,/]|\s)
# (/|\s)Pro\*C([,/]|\s)
# (/|\s)Pure([,/]|\s)
# (/|\s)Pure\ Data([,/]|\s)
# (/|\s)PureScript([,/]|\s)
# (/|\s)Python([,/]|\s)
# (/|\s)Q([,/]|\s)
# (/|\s)Q\#([,/]|\s)
# (/|\s)Qalb([,/]|\s)
# (/|\s)Quantum\ Computation\ Language([,/]|\s)
# (/|\s)QtScript([,/]|\s)
# (/|\s)QuakeC([,/]|\s)
# (/|\s)QPL([,/]|\s)
# (/|\s)\.QL([,/]|\s)
# (/|\s)R([,/]|\s)
# (/|\s)R\+\+([,/]|\s)
# (/|\s)Racket([,/]|\s)
# (/|\s)Raku([,/]|\s)
# (/|\s)RAPID([,/]|\s)
# (/|\s)Rapira([,/]|\s)
# (/|\s)Ratfiv([,/]|\s)
# (/|\s)Ratfor([,/]|\s)
# (/|\s)rc([,/]|\s)
# (/|\s)Reason([,/]|\s)
# (/|\s)REBOL([,/]|\s)
# (/|\s)Red([,/]|\s)
# (/|\s)Redcode([,/]|\s)
# (/|\s)REFAL([,/]|\s)
# (/|\s)REXX([,/]|\s)
# (/|\s)Rlab([,/]|\s)
# (/|\s)ROOP([,/]|\s)
# (/|\s)RPG([,/]|\s)
# (/|\s)RPL([,/]|\s)
# (/|\s)RSL([,/]|\s)
# (/|\s)RTL/2([,/]|\s)
# (/|\s)Ruby([,/]|\s)
# (/|\s)Rust([,/]|\s)
# (/|\s)S([,/]|\s)
# (/|\s)S2([,/]|\s)
# (/|\s)S3([,/]|\s)
# (/|\s)S\-Lang([,/]|\s)
# (/|\s)S\-PLUS([,/]|\s)
# (/|\s)SA\-C([,/]|\s)
# (/|\s)SabreTalk([,/]|\s)
# (/|\s)SAIL([,/]|\s)
# (/|\s)SAS([,/]|\s)
# (/|\s)SASL([,/]|\s)
# (/|\s)Sather([,/]|\s)
# (/|\s)Sawzall([,/]|\s)
# (/|\s)Scala([,/]|\s)
# (/|\s)Scheme([,/]|\s)
# (/|\s)Scilab([,/]|\s)
# (/|\s)Scratch([,/]|\s)
# (/|\s)Script\.NET([,/]|\s)
# (/|\s)Sed([,/]|\s)
# (/|\s)Seed7([,/]|\s)
# (/|\s)Self([,/]|\s)
# (/|\s)SenseTalk([,/]|\s)
# (/|\s)SequenceL([,/]|\s)
# (/|\s)Serpent([,/]|\s)
# (/|\s)SETL([,/]|\s)
# (/|\s)SIMPOL([,/]|\s)
# (/|\s)SIGNAL([,/]|\s)
# (/|\s)SiMPLE([,/]|\s)
# (/|\s)SIMSCRIPT([,/]|\s)
# (/|\s)Simula([,/]|\s)
# (/|\s)Simulink([,/]|\s)
# (/|\s)Singularity([,/]|\s)
# (/|\s)SISAL([,/]|\s)
# (/|\s)SLIP([,/]|\s)
# (/|\s)SMALL([,/]|\s)
# (/|\s)Smalltalk([,/]|\s)
# (/|\s)SML([,/]|\s)
# (/|\s)Strongtalk([,/]|\s)
# (/|\s)Snap!([,/]|\s)
# (/|\s)SNOBOL([,/]|\s)
# (/|\s)Snowball([,/]|\s)
# (/|\s)SOL([,/]|\s)
# (/|\s)Solidity([,/]|\s)
# (/|\s)SOPHAEROS([,/]|\s)
# (/|\s)Source([,/]|\s)
# (/|\s)SPARK([,/]|\s)
# (/|\s)Speakeasy([,/]|\s)
# (/|\s)Speedcode([,/]|\s)
# (/|\s)SPIN([,/]|\s)
# (/|\s)SP/k([,/]|\s)
# (/|\s)SPS([,/]|\s)
# (/|\s)SQL([,/]|\s)
# (/|\s)SQR([,/]|\s)
# (/|\s)Squeak([,/]|\s)
# (/|\s)Squirrel([,/]|\s)
# (/|\s)SR([,/]|\s)
# (/|\s)S/SL([,/]|\s)
# (/|\s)Starlogo([,/]|\s)
# (/|\s)Strand([,/]|\s)
# (/|\s)Stata([,/]|\s)
# (/|\s)Stateflow([,/]|\s)
# (/|\s)Subtext([,/]|\s)
# (/|\s)SBL([,/]|\s)
# (/|\s)SuperCollider([,/]|\s)
# (/|\s)SuperTalk([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)SYMPL([,/]|\s)
# (/|\s)SystemVerilog([,/]|\s)
# (/|\s)T([,/]|\s)
# (/|\s)TACL([,/]|\s)
# (/|\s)TACPOL([,/]|\s)
# (/|\s)TADS([,/]|\s)
# (/|\s)TAL([,/]|\s)
# (/|\s)Tcl([,/]|\s)
# (/|\s)Tea([,/]|\s)
# (/|\s)TECO([,/]|\s)
# (/|\s)TELCOMP([,/]|\s)
# (/|\s)TeX([,/]|\s)
# (/|\s)TEX([,/]|\s)
# (/|\s)TIE([,/]|\s)
# (/|\s)TMG([,/]|\s)
# (/|\s)Tom([,/]|\s)
# (/|\s)Toi([,/]|\s)
# (/|\s)Topspeed([,/]|\s)
# (/|\s)TPU([,/]|\s)
# (/|\s)Trac([,/]|\s)
# (/|\s)TTM([,/]|\s)
# (/|\s)T\-SQL([,/]|\s)
# (/|\s)Transcript([,/]|\s)
# (/|\s)TTCN([,/]|\s)
# (/|\s)Turing([,/]|\s)
# (/|\s)TUTOR([,/]|\s)
# (/|\s)TXL([,/]|\s)
# (/|\s)TypeScript([,/]|\s)
# (/|\s)Tynker([,/]|\s)
# (/|\s)Ubercode([,/]|\s)
# (/|\s)UCSD\ Pascal([,/]|\s)
# (/|\s)Umple([,/]|\s)
# (/|\s)Unicon([,/]|\s)
# (/|\s)Uniface([,/]|\s)
# (/|\s)UNITY([,/]|\s)
# (/|\s)Unix\ shell([,/]|\s)
# (/|\s)UnrealScript([,/]|\s)
# (/|\s)Vala([,/]|\s)
# (/|\s)Verilog([,/]|\s)
# (/|\s)VHDL([,/]|\s)
# (/|\s)Vim\ script([,/]|\s)
# (/|\s)Viper([,/]|\s)
# (/|\s)Visual\ DataFlex([,/]|\s)
# (/|\s)Visual\ DialogScript([,/]|\s)
# (/|\s)Visual\ FoxPro([,/]|\s)
# (/|\s)Visual\ J\+\+([,/]|\s)
# (/|\s)Visual\ LISP([,/]|\s)
# (/|\s)Visual\ Objects([,/]|\s)
# (/|\s)Visual\ Prolog([,/]|\s)
# (/|\s)WATFIV,\ WATFOR([,/]|\s)
# (/|\s)WebAssembly([,/]|\s)
# (/|\s)WebDNA([,/]|\s)
# (/|\s)Whiley([,/]|\s)
# (/|\s)Winbatch([,/]|\s)
# (/|\s)Wolfram\ Language([,/]|\s)
# (/|\s)Wyvern([,/]|\s)
# (/|\s)X\+\+([,/]|\s)
# (/|\s)X10([,/]|\s)
# (/|\s)xBase([,/]|\s)
# (/|\s)xBase\+\+([,/]|\s)
# (/|\s)XBL([,/]|\s)
# (/|\s)XC([,/]|\s)
# (/|\s)xHarbour([,/]|\s)
# (/|\s)XL([,/]|\s)
# (/|\s)Xojo([,/]|\s)
# (/|\s)XOTcl([,/]|\s)
# (/|\s)Xod([,/]|\s)
# (/|\s)XPL([,/]|\s)
# (/|\s)XPL0([,/]|\s)
# (/|\s)XQuery([,/]|\s)
# (/|\s)XSB([,/]|\s)
# (/|\s)XSharp([,/]|\s)
# (/|\s)XSLT([,/]|\s)
# (/|\s)Xtend([,/]|\s)
# (/|\s)Yorick([,/]|\s)
# (/|\s)YQL([,/]|\s)
# (/|\s)Yoix([,/]|\s)
# (/|\s)YUI([,/]|\s)
# (/|\s)Z\ notation([,/]|\s)
# (/|\s)Zebra,\ ZPL,\ ZPL2([,/]|\s)
# (/|\s)Zeno([,/]|\s)
# (/|\s)ZetaLisp([,/]|\s)
# (/|\s)Zig([,/]|\s)
# (/|\s)ZOPL([,/]|\s)
# (/|\s)ZPL([,/]|\s)
# (/|\s)Z\+\+([,/]|\s)

# %%
scraped_df["job_subsection"].unique()
# Out:
# array(['Networks & Systems Administration', 'Management', 'Consultants',
#        'Help Desk & IT Support', 'Programme & Project Management',
#        'Team Leaders', 'Product Management & Development',
#        'Database Development & Administration', 'Engineering - Software',
#        'Computer Operators', 'Architects', 'Business/Systems Analysts',
#        'Developers/Programmers', 'Security',
#        'Testing & Quality Assurance', 'Other', 'Engineering - Network',
#        'Engineering - Hardware', 'Technical Writing',
#        'Telecommunications', 'Sales - Pre & Post',
#        'Web Development & Production'], dtype=object)

# %%
sub_count_df
# Out:
#            lang  count
# 0        A.NET       0
# 1    A-0 System      0
# 2           A+       0
# 3          ABAP      0
# 4           ABC      0
# ..          ...    ...
# 680    ZetaLisp      0
# 681         Zig      0
# 682        ZOPL      0
# 683         ZPL      0
# 684         Z++      0
#
# [685 rows x 2 columns]

# %%
subs = scraped_df["job_subsection"].unique()

for sub in subs:
    sub_df = scraped_df.loc[scraped_df["job_subsection"] == sub]
    content = sub_df["fixed_content"].values
    sub_count_df = pd.DataFrame()
    sub_count_df["lang"] = lang_df["fixed"]; sub_count_df["count"] = 0
    for i in sub_count_df.index:
        # lang = "".join(list(map(lambda o: r"\\" +o , list(count_df["lang"].loc[i].strip()))))
        lang = re.escape(sub_count_df["lang"].loc[i].strip())         
        exp = r"(/|\s)"+lang+r"([,/]|\s)"
        print(exp)
        for j in content:
            if re.search(exp, j, re.IGNORECASE):
                sub_count_df["count"].loc[i] += 1
    sub_count_df.to_csv(f"data/subsections/{sub}_lang_count.csv")
# Out:
# (/|\s)A\.NET([,/]|\s)
# (/|\s)A\-0\ System([,/]|\s)
# (/|\s)A\+([,/]|\s)
# (/|\s)ABAP([,/]|\s)
# (/|\s)ABC([,/]|\s)
# (/|\s)ABC\ ALGOL([,/]|\s)
# (/|\s)ACC([,/]|\s)
# (/|\s)Accent([,/]|\s)
# (/|\s)Ace\ DASL([,/]|\s)
# (/|\s)Action!([,/]|\s)
# (/|\s)ActionScript([,/]|\s)
# (/|\s)Actor([,/]|\s)
# (/|\s)Ada([,/]|\s)
# (/|\s)Adenine([,/]|\s)
# (/|\s)AdvPL([,/]|\s)
# (/|\s)Agda([,/]|\s)
# (/|\s)Agilent\ VEE([,/]|\s)
# (/|\s)Agora([,/]|\s)
# (/|\s)AIMMS([,/]|\s)
# (/|\s)Aldor([,/]|\s)
# (/|\s)Alef([,/]|\s)
# (/|\s)ALF([,/]|\s)
# (/|\s)ALGOL\ 58([,/]|\s)
# (/|\s)ALGOL\ 60([,/]|\s)
# (/|\s)ALGOL\ 68([,/]|\s)
# (/|\s)ALGOL\ W([,/]|\s)
# (/|\s)Alice([,/]|\s)
# (/|\s)Alma\-0([,/]|\s)
# (/|\s)AmbientTalk([,/]|\s)
# C:\Users\sloth\anaconda3\envs\scraper\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# (/|\s)Amiga\ E([,/]|\s)
# (/|\s)AMOS([,/]|\s)
# (/|\s)AMPL([,/]|\s)
# (/|\s)AngelScript([,/]|\s)
# (/|\s)Apache\ Pig\ latin([,/]|\s)
# (/|\s)Apex([,/]|\s)
# (/|\s)APL([,/]|\s)
# (/|\s)App\ Inventor\ for\ Android's\ visual\ block\ language([,/]|\s)
# (/|\s)AppleScript([,/]|\s)
# (/|\s)APT([,/]|\s)
# (/|\s)Arc([,/]|\s)
# (/|\s)ARexx([,/]|\s)
# (/|\s)Argus([,/]|\s)
# (/|\s)Assembly\ language([,/]|\s)
# (/|\s)AutoIt([,/]|\s)
# (/|\s)AutoLISP\ /\ Visual\ LISP([,/]|\s)
# (/|\s)Averest([,/]|\s)
# (/|\s)AWK([,/]|\s)
# (/|\s)Axum([,/]|\s)
# (/|\s)B([,/]|\s)
# (/|\s)Babbage([,/]|\s)
# (/|\s)Ballerina([,/]|\s)
# (/|\s)Bash([,/]|\s)
# (/|\s)BASIC([,/]|\s)
# (/|\s)Batch\ file([,/]|\s)
# (/|\s)bc([,/]|\s)
# (/|\s)BCPL([,/]|\s)
# (/|\s)BeanShell([,/]|\s)
# (/|\s)Bertrand([,/]|\s)
# (/|\s)BETA([,/]|\s)
# (/|\s)BLISS([,/]|\s)
# (/|\s)Blockly([,/]|\s)
# (/|\s)BlooP([,/]|\s)
# (/|\s)Boo([,/]|\s)
# (/|\s)Boomerang([,/]|\s)
# (/|\s)Bosque([,/]|\s)
# (/|\s)C\ –\ ISO/IEC\ 9899([,/]|\s)
# (/|\s)C\-\-([,/]|\s)
# (/|\s)C\+\+([,/]|\s)
# (/|\s)C\*([,/]|\s)
# (/|\s)C\#([,/]|\s)
# (/|\s)C/AL([,/]|\s)
# (/|\s)Caché\ ObjectScript([,/]|\s)
# (/|\s)C\ Shell([,/]|\s)
# (/|\s)Caml([,/]|\s)
# (/|\s)Cayenne([,/]|\s)
# (/|\s)CDuce([,/]|\s)
# (/|\s)Cecil([,/]|\s)
# (/|\s)Cesil([,/]|\s)
# (/|\s)Céu([,/]|\s)
# (/|\s)Ceylon([,/]|\s)
# (/|\s)CFEngine([,/]|\s)
# (/|\s)Cg([,/]|\s)
# (/|\s)Ch([,/]|\s)
# (/|\s)Chapel([,/]|\s)
# (/|\s)Charm([,/]|\s)
# (/|\s)CHILL([,/]|\s)
# (/|\s)CHIP\-8([,/]|\s)
# (/|\s)ChucK([,/]|\s)
# (/|\s)Cilk([,/]|\s)
# (/|\s)CL([,/]|\s)
# (/|\s)Claire([,/]|\s)
# (/|\s)Clarion([,/]|\s)
# (/|\s)Clean([,/]|\s)
# (/|\s)Clipper([,/]|\s)
# (/|\s)CLIPS([,/]|\s)
# (/|\s)CLIST([,/]|\s)
# (/|\s)Clojure([,/]|\s)
# (/|\s)CLU([,/]|\s)
# (/|\s)CMS\-2([,/]|\s)
# (/|\s)COBOL\ –\ ISO/IEC\ 1989([,/]|\s)
# (/|\s)CobolScript\ –\ COBOL\ Scripting\ language([,/]|\s)
# (/|\s)Cobra([,/]|\s)
# (/|\s)CoffeeScript([,/]|\s)
# (/|\s)ColdFusion([,/]|\s)
# (/|\s)COMAL([,/]|\s)
# (/|\s)Combined\ Programming\ Language([,/]|\s)
# (/|\s)COMIT([,/]|\s)
# (/|\s)Common\ Intermediate\ Language([,/]|\s)
# (/|\s)Common\ Lisp([,/]|\s)
# (/|\s)COMPASS([,/]|\s)
# (/|\s)Component\ Pascal([,/]|\s)
# (/|\s)Constraint\ Handling\ Rules([,/]|\s)
# (/|\s)COMTRAN([,/]|\s)
# (/|\s)Cool([,/]|\s)
# (/|\s)Coq([,/]|\s)
# (/|\s)Coral\ 66([,/]|\s)
# (/|\s)CorVision([,/]|\s)
# (/|\s)COWSEL([,/]|\s)
# (/|\s)CPL([,/]|\s)
# (/|\s)Cryptol([,/]|\s)
# (/|\s)Crystal([,/]|\s)
# (/|\s)Csound([,/]|\s)
# (/|\s)Cuneiform([,/]|\s)
# (/|\s)Curl([,/]|\s)
# (/|\s)Curry([,/]|\s)
# (/|\s)Cybil([,/]|\s)
# (/|\s)Cyclone([,/]|\s)
# (/|\s)Cypher\ Query\ Language([,/]|\s)
# (/|\s)Cython([,/]|\s)
# (/|\s)CEEMAC([,/]|\s)
# (/|\s)D([,/]|\s)
# (/|\s)Dart([,/]|\s)
# (/|\s)Darwin([,/]|\s)
# (/|\s)DataFlex([,/]|\s)
# (/|\s)Datalog([,/]|\s)
# (/|\s)DATATRIEVE([,/]|\s)
# (/|\s)dBase([,/]|\s)
# (/|\s)dc([,/]|\s)
# (/|\s)DCL([,/]|\s)
# (/|\s)Delphi([,/]|\s)
# (/|\s)DinkC([,/]|\s)
# (/|\s)DIBOL([,/]|\s)
# (/|\s)Dog([,/]|\s)
# (/|\s)Draco([,/]|\s)
# (/|\s)DRAKON([,/]|\s)
# (/|\s)Dylan([,/]|\s)
# (/|\s)DYNAMO([,/]|\s)
# (/|\s)DAX([,/]|\s)
# (/|\s)E([,/]|\s)
# (/|\s)Ease([,/]|\s)
# (/|\s)Easy\ PL/I([,/]|\s)
# (/|\s)EASYTRIEVE\ PLUS([,/]|\s)
# (/|\s)eC([,/]|\s)
# (/|\s)ECMAScript([,/]|\s)
# (/|\s)Edinburgh\ IMP([,/]|\s)
# (/|\s)EGL([,/]|\s)
# (/|\s)Eiffel([,/]|\s)
# (/|\s)ELAN([,/]|\s)
# (/|\s)Elixir([,/]|\s)
# (/|\s)Elm([,/]|\s)
# (/|\s)Emacs\ Lisp([,/]|\s)
# (/|\s)Emerald([,/]|\s)
# (/|\s)Epigram([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)Erlang([,/]|\s)
# (/|\s)es([,/]|\s)
# (/|\s)Escher([,/]|\s)
# (/|\s)ESPOL([,/]|\s)
# (/|\s)Esterel([,/]|\s)
# (/|\s)Etoys([,/]|\s)
# (/|\s)Euclid([,/]|\s)
# (/|\s)Euler([,/]|\s)
# (/|\s)Euphoria([,/]|\s)
# (/|\s)EusLisp\ Robot\ Programming\ Language([,/]|\s)
# (/|\s)CMS\ EXEC([,/]|\s)
# (/|\s)EXEC\ 2([,/]|\s)
# (/|\s)Executable\ UML([,/]|\s)
# (/|\s)Ezhil([,/]|\s)
# (/|\s)F([,/]|\s)
# (/|\s)F\#([,/]|\s)
# (/|\s)F\*([,/]|\s)
# (/|\s)Factor([,/]|\s)
# (/|\s)Fantom([,/]|\s)
# (/|\s)FAUST([,/]|\s)
# (/|\s)FFP([,/]|\s)
# (/|\s)fish([,/]|\s)
# (/|\s)Fjölnir([,/]|\s)
# (/|\s)FL([,/]|\s)
# (/|\s)Flavors([,/]|\s)
# (/|\s)Flex([,/]|\s)
# (/|\s)Flix([,/]|\s)
# (/|\s)FlooP([,/]|\s)
# (/|\s)FLOW\-MASTIC([,/]|\s)
# (/|\s)FOCAL([,/]|\s)
# (/|\s)FOCUS([,/]|\s)
# (/|\s)FOIL([,/]|\s)
# (/|\s)FORMAC([,/]|\s)
# (/|\s)@Formula([,/]|\s)
# (/|\s)Forth([,/]|\s)
# (/|\s)Fortran\ –\ ISO/IEC\ 1539([,/]|\s)
# (/|\s)Fortress([,/]|\s)
# (/|\s)FP([,/]|\s)
# (/|\s)Franz\ Lisp([,/]|\s)
# (/|\s)Futhark([,/]|\s)
# (/|\s)F\-Script([,/]|\s)
# (/|\s)Game\ Maker\ Language([,/]|\s)
# (/|\s)GameMonkey\ Script([,/]|\s)
# (/|\s)GAMS([,/]|\s)
# (/|\s)GAP([,/]|\s)
# (/|\s)G\-code([,/]|\s)
# (/|\s)GDScript([,/]|\s)
# (/|\s)Genie([,/]|\s)
# (/|\s)GDL([,/]|\s)
# (/|\s)GEORGE([,/]|\s)
# (/|\s)GLSL([,/]|\s)
# (/|\s)GNU\ E([,/]|\s)
# (/|\s)GNU\ Guile([,/]|\s)
# (/|\s)Go([,/]|\s)
# (/|\s)Go!([,/]|\s)
# (/|\s)GOAL([,/]|\s)
# (/|\s)Gödel([,/]|\s)
# (/|\s)Golo([,/]|\s)
# (/|\s)GOM([,/]|\s)
# (/|\s)Google\ Apps\ Script([,/]|\s)
# (/|\s)Gosu([,/]|\s)
# (/|\s)GOTRAN([,/]|\s)
# (/|\s)GPSS([,/]|\s)
# (/|\s)GraphTalk([,/]|\s)
# (/|\s)GRASS([,/]|\s)
# (/|\s)Grasshopper([,/]|\s)
# (/|\s)Groovy([,/]|\s)
# (/|\s)Hack([,/]|\s)
# (/|\s)HAGGIS([,/]|\s)
# (/|\s)HAL/S([,/]|\s)
# (/|\s)Halide([,/]|\s)
# (/|\s)Hamilton\ C\ shell([,/]|\s)
# (/|\s)Harbour([,/]|\s)
# (/|\s)Hartmann\ pipelines([,/]|\s)
# (/|\s)Haskell([,/]|\s)
# (/|\s)Haxe([,/]|\s)
# (/|\s)Hermes([,/]|\s)
# (/|\s)High\ Level\ Assembly([,/]|\s)
# (/|\s)HLSL([,/]|\s)
# (/|\s)Hollywood([,/]|\s)
# (/|\s)HolyC([,/]|\s)
# (/|\s)Hop([,/]|\s)
# (/|\s)Hopscotch([,/]|\s)
# (/|\s)Hope([,/]|\s)
# (/|\s)Hugo([,/]|\s)
# (/|\s)Hume([,/]|\s)
# (/|\s)HyperTalk([,/]|\s)
# (/|\s)Io([,/]|\s)
# (/|\s)Icon([,/]|\s)
# (/|\s)IBM\ Basic\ assembly\ language([,/]|\s)
# (/|\s)IBM\ HAScript([,/]|\s)
# (/|\s)IBM\ Informix\-4GL([,/]|\s)
# (/|\s)IBM\ RPG([,/]|\s)
# (/|\s)IDL([,/]|\s)
# (/|\s)Idris([,/]|\s)
# (/|\s)Inform([,/]|\s)
# (/|\s)J([,/]|\s)
# (/|\s)J\#([,/]|\s)
# (/|\s)J\+\+([,/]|\s)
# (/|\s)JADE([,/]|\s)
# (/|\s)Jai([,/]|\s)
# (/|\s)JAL([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)JASS([,/]|\s)
# (/|\s)Java([,/]|\s)
# (/|\s)JavaFX\ Script([,/]|\s)
# (/|\s)JavaScript([,/]|\s)
# (/|\s)Jess([,/]|\s)
# (/|\s)JCL([,/]|\s)
# (/|\s)JEAN([,/]|\s)
# (/|\s)Join\ Java([,/]|\s)
# (/|\s)JOSS([,/]|\s)
# (/|\s)Joule([,/]|\s)
# (/|\s)JOVIAL([,/]|\s)
# (/|\s)Joy([,/]|\s)
# (/|\s)JScript([,/]|\s)
# (/|\s)JScript\ \.NET([,/]|\s)
# (/|\s)Julia([,/]|\s)
# (/|\s)Jython([,/]|\s)
# (/|\s)K([,/]|\s)
# (/|\s)Kaleidoscope([,/]|\s)
# (/|\s)Karel([,/]|\s)
# (/|\s)KEE([,/]|\s)
# (/|\s)Kixtart([,/]|\s)
# (/|\s)Klerer\-May\ System([,/]|\s)
# (/|\s)KIF([,/]|\s)
# (/|\s)Kojo([,/]|\s)
# (/|\s)Kotlin([,/]|\s)
# (/|\s)KRC([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRYPTON([,/]|\s)
# (/|\s)KornShell([,/]|\s)
# (/|\s)Kodu([,/]|\s)
# (/|\s)Kv([,/]|\s)
# (/|\s)LabVIEW([,/]|\s)
# (/|\s)Ladder([,/]|\s)
# (/|\s)LANSA([,/]|\s)
# (/|\s)Lasso([,/]|\s)
# (/|\s)Lava([,/]|\s)
# (/|\s)LC\-3([,/]|\s)
# (/|\s)Lean([,/]|\s)
# (/|\s)Legoscript([,/]|\s)
# (/|\s)LIL([,/]|\s)
# (/|\s)LilyPond([,/]|\s)
# (/|\s)Limbo([,/]|\s)
# (/|\s)Limnor([,/]|\s)
# (/|\s)LINC([,/]|\s)
# (/|\s)Lingo([,/]|\s)
# (/|\s)LINQ([,/]|\s)
# (/|\s)LIS([,/]|\s)
# (/|\s)LISA([,/]|\s)
# (/|\s)Language\ H([,/]|\s)
# (/|\s)Lisp\ –\ ISO/IEC\ 13816([,/]|\s)
# (/|\s)Lite\-C([,/]|\s)
# (/|\s)Lithe([,/]|\s)
# (/|\s)Little\ b([,/]|\s)
# (/|\s)LLL([,/]|\s)
# (/|\s)Logo([,/]|\s)
# (/|\s)Logtalk([,/]|\s)
# (/|\s)LotusScript([,/]|\s)
# (/|\s)LPC([,/]|\s)
# (/|\s)LSE([,/]|\s)
# (/|\s)LSL([,/]|\s)
# (/|\s)LiveCode([,/]|\s)
# (/|\s)LiveScript([,/]|\s)
# (/|\s)Lua([,/]|\s)
# (/|\s)Lucid([,/]|\s)
# (/|\s)Lustre([,/]|\s)
# (/|\s)LYaPAS([,/]|\s)
# (/|\s)Lynx([,/]|\s)
# (/|\s)M2001([,/]|\s)
# (/|\s)M4([,/]|\s)
# (/|\s)M\#([,/]|\s)
# (/|\s)Machine\ code([,/]|\s)
# (/|\s)MAD([,/]|\s)
# (/|\s)MAD/I([,/]|\s)
# (/|\s)Magik([,/]|\s)
# (/|\s)Magma([,/]|\s)
# (/|\s)Máni([,/]|\s)
# (/|\s)Maple([,/]|\s)
# (/|\s)MAPPER([,/]|\s)
# (/|\s)MARK\-IV([,/]|\s)
# (/|\s)Mary([,/]|\s)
# (/|\s)MATLAB([,/]|\s)
# (/|\s)MASM\ Microsoft\ Assembly\ x86([,/]|\s)
# (/|\s)MATH\-MATIC([,/]|\s)
# (/|\s)Maude\ system([,/]|\s)
# (/|\s)Maxima([,/]|\s)
# (/|\s)Max([,/]|\s)
# (/|\s)MaxScript\ internal\ language\ 3D\ Studio\ Max([,/]|\s)
# (/|\s)Maya([,/]|\s)
# (/|\s)MDL([,/]|\s)
# (/|\s)Mercury([,/]|\s)
# (/|\s)Mesa([,/]|\s)
# (/|\s)MHEG\-5([,/]|\s)
# (/|\s)Microcode([,/]|\s)
# (/|\s)MicroScript([,/]|\s)
# (/|\s)Microsoft\ Power\ Fx([,/]|\s)
# (/|\s)MIIS([,/]|\s)
# (/|\s)Milk([,/]|\s)
# (/|\s)MIMIC([,/]|\s)
# (/|\s)Mirah([,/]|\s)
# (/|\s)Miranda([,/]|\s)
# (/|\s)MIVA\ Script([,/]|\s)
# (/|\s)ML([,/]|\s)
# (/|\s)Model\ 204([,/]|\s)
# (/|\s)Modelica([,/]|\s)
# (/|\s)Modula([,/]|\s)
# (/|\s)Modula\-2([,/]|\s)
# (/|\s)Modula\-3([,/]|\s)
# (/|\s)Mohol([,/]|\s)
# (/|\s)MOO([,/]|\s)
# (/|\s)Mortran([,/]|\s)
# (/|\s)Mouse([,/]|\s)
# (/|\s)MPD([,/]|\s)
# (/|\s)MSL([,/]|\s)
# (/|\s)MUMPS([,/]|\s)
# (/|\s)MuPAD([,/]|\s)
# (/|\s)Mutan([,/]|\s)
# (/|\s)Mystic\ Programming\ Language([,/]|\s)
# (/|\s)NASM([,/]|\s)
# (/|\s)Napier88([,/]|\s)
# (/|\s)Neko([,/]|\s)
# (/|\s)Nemerle([,/]|\s)
# (/|\s)NESL([,/]|\s)
# (/|\s)Net\.Data([,/]|\s)
# (/|\s)NetLogo([,/]|\s)
# (/|\s)NetRexx([,/]|\s)
# (/|\s)NewLISP([,/]|\s)
# (/|\s)NEWP([,/]|\s)
# (/|\s)Newspeak([,/]|\s)
# (/|\s)NewtonScript([,/]|\s)
# (/|\s)Nial([,/]|\s)
# (/|\s)Nickle([,/]|\s)
# (/|\s)Nim([,/]|\s)
# (/|\s)Nix([,/]|\s)
# (/|\s)NPL([,/]|\s)
# (/|\s)Not\ eXactly\ C([,/]|\s)
# (/|\s)Not\ Quite\ C([,/]|\s)
# (/|\s)NSIS([,/]|\s)
# (/|\s)Nu([,/]|\s)
# (/|\s)NWScript([,/]|\s)
# (/|\s)NXT\-G([,/]|\s)
# (/|\s)o:XML([,/]|\s)
# (/|\s)Oak([,/]|\s)
# (/|\s)Oberon([,/]|\s)
# (/|\s)OBJ2([,/]|\s)
# (/|\s)Object\ Lisp([,/]|\s)
# (/|\s)ObjectLOGO([,/]|\s)
# (/|\s)Object\ REXX([,/]|\s)
# (/|\s)Object\ Pascal([,/]|\s)
# (/|\s)Objective\-C([,/]|\s)
# (/|\s)Objective\-J([,/]|\s)
# (/|\s)Obliq([,/]|\s)
# (/|\s)OCaml([,/]|\s)
# (/|\s)occam([,/]|\s)
# (/|\s)occam\-π([,/]|\s)
# (/|\s)Octave([,/]|\s)
# (/|\s)OmniMark([,/]|\s)
# (/|\s)Opa([,/]|\s)
# (/|\s)Opal([,/]|\s)
# (/|\s)OpenCL([,/]|\s)
# (/|\s)OpenEdge\ ABL([,/]|\s)
# (/|\s)OPL([,/]|\s)
# (/|\s)OpenVera([,/]|\s)
# (/|\s)OPS5([,/]|\s)
# (/|\s)OptimJ([,/]|\s)
# (/|\s)Orc([,/]|\s)
# (/|\s)ORCA/Modula\-2([,/]|\s)
# (/|\s)Oriel([,/]|\s)
# (/|\s)Orwell([,/]|\s)
# (/|\s)Oxygene([,/]|\s)
# (/|\s)Oz([,/]|\s)
# (/|\s)P([,/]|\s)
# (/|\s)P4([,/]|\s)
# (/|\s)P′′([,/]|\s)
# (/|\s)ParaSail([,/]|\s)
# (/|\s)PARI/GP([,/]|\s)
# (/|\s)Pascal\ –\ ISO\ 7185([,/]|\s)
# (/|\s)Pascal\ Script([,/]|\s)
# (/|\s)PCASTL([,/]|\s)
# (/|\s)PCF([,/]|\s)
# (/|\s)PEARL([,/]|\s)
# (/|\s)PeopleCode([,/]|\s)
# (/|\s)Perl([,/]|\s)
# (/|\s)PDL([,/]|\s)
# (/|\s)Pharo([,/]|\s)
# (/|\s)PHP([,/]|\s)
# (/|\s)Pico([,/]|\s)
# (/|\s)Picolisp([,/]|\s)
# (/|\s)Pict([,/]|\s)
# (/|\s)Pike([,/]|\s)
# (/|\s)PILOT([,/]|\s)
# (/|\s)Pipelines([,/]|\s)
# (/|\s)Pizza([,/]|\s)
# (/|\s)PL\-11([,/]|\s)
# (/|\s)PL/0([,/]|\s)
# (/|\s)PL/B([,/]|\s)
# (/|\s)PL/C([,/]|\s)
# (/|\s)PL/I\ –\ ISO\ 6160([,/]|\s)
# (/|\s)PL/M([,/]|\s)
# (/|\s)PL/P([,/]|\s)
# (/|\s)PL/SQL([,/]|\s)
# (/|\s)PL360([,/]|\s)
# (/|\s)PLANC([,/]|\s)
# (/|\s)Plankalkül([,/]|\s)
# (/|\s)Planner([,/]|\s)
# (/|\s)PLEX([,/]|\s)
# (/|\s)PLEXIL([,/]|\s)
# (/|\s)Plus([,/]|\s)
# (/|\s)POP\-11([,/]|\s)
# (/|\s)POP\-2([,/]|\s)
# (/|\s)PostScript([,/]|\s)
# (/|\s)PortablE([,/]|\s)
# (/|\s)POV\-Ray\ SDL([,/]|\s)
# (/|\s)Powerhouse([,/]|\s)
# (/|\s)PowerBuilder\ –\ 4GL\ GUI\ application\ generator\ from\ Sybase([,/]|\s)
# (/|\s)PowerShell([,/]|\s)
# (/|\s)PPL([,/]|\s)
# (/|\s)Processing([,/]|\s)
# (/|\s)Processing\.js([,/]|\s)
# (/|\s)Prograph([,/]|\s)
# (/|\s)PROIV([,/]|\s)
# (/|\s)Project\ Verona([,/]|\s)
# (/|\s)Prolog([,/]|\s)
# (/|\s)PROMAL([,/]|\s)
# (/|\s)Promela([,/]|\s)
# (/|\s)PROSE\ modeling\ language([,/]|\s)
# (/|\s)PROTEL([,/]|\s)
# (/|\s)ProvideX([,/]|\s)
# (/|\s)Pro\*C([,/]|\s)
# (/|\s)Pure([,/]|\s)
# (/|\s)Pure\ Data([,/]|\s)
# (/|\s)PureScript([,/]|\s)
# (/|\s)Python([,/]|\s)
# (/|\s)Q([,/]|\s)
# (/|\s)Q\#([,/]|\s)
# (/|\s)Qalb([,/]|\s)
# (/|\s)Quantum\ Computation\ Language([,/]|\s)
# (/|\s)QtScript([,/]|\s)
# (/|\s)QuakeC([,/]|\s)
# (/|\s)QPL([,/]|\s)
# (/|\s)\.QL([,/]|\s)
# (/|\s)R([,/]|\s)
# (/|\s)R\+\+([,/]|\s)
# (/|\s)Racket([,/]|\s)
# (/|\s)Raku([,/]|\s)
# (/|\s)RAPID([,/]|\s)
# (/|\s)Rapira([,/]|\s)
# (/|\s)Ratfiv([,/]|\s)
# (/|\s)Ratfor([,/]|\s)
# (/|\s)rc([,/]|\s)
# (/|\s)Reason([,/]|\s)
# (/|\s)REBOL([,/]|\s)
# (/|\s)Red([,/]|\s)
# (/|\s)Redcode([,/]|\s)
# (/|\s)REFAL([,/]|\s)
# (/|\s)REXX([,/]|\s)
# (/|\s)Rlab([,/]|\s)
# (/|\s)ROOP([,/]|\s)
# (/|\s)RPG([,/]|\s)
# (/|\s)RPL([,/]|\s)
# (/|\s)RSL([,/]|\s)
# (/|\s)RTL/2([,/]|\s)
# (/|\s)Ruby([,/]|\s)
# (/|\s)Rust([,/]|\s)
# (/|\s)S([,/]|\s)
# (/|\s)S2([,/]|\s)
# (/|\s)S3([,/]|\s)
# (/|\s)S\-Lang([,/]|\s)
# (/|\s)S\-PLUS([,/]|\s)
# (/|\s)SA\-C([,/]|\s)
# (/|\s)SabreTalk([,/]|\s)
# (/|\s)SAIL([,/]|\s)
# (/|\s)SAS([,/]|\s)
# (/|\s)SASL([,/]|\s)
# (/|\s)Sather([,/]|\s)
# (/|\s)Sawzall([,/]|\s)
# (/|\s)Scala([,/]|\s)
# (/|\s)Scheme([,/]|\s)
# (/|\s)Scilab([,/]|\s)
# (/|\s)Scratch([,/]|\s)
# (/|\s)Script\.NET([,/]|\s)
# (/|\s)Sed([,/]|\s)
# (/|\s)Seed7([,/]|\s)
# (/|\s)Self([,/]|\s)
# (/|\s)SenseTalk([,/]|\s)
# (/|\s)SequenceL([,/]|\s)
# (/|\s)Serpent([,/]|\s)
# (/|\s)SETL([,/]|\s)
# (/|\s)SIMPOL([,/]|\s)
# (/|\s)SIGNAL([,/]|\s)
# (/|\s)SiMPLE([,/]|\s)
# (/|\s)SIMSCRIPT([,/]|\s)
# (/|\s)Simula([,/]|\s)
# (/|\s)Simulink([,/]|\s)
# (/|\s)Singularity([,/]|\s)
# (/|\s)SISAL([,/]|\s)
# (/|\s)SLIP([,/]|\s)
# (/|\s)SMALL([,/]|\s)
# (/|\s)Smalltalk([,/]|\s)
# (/|\s)SML([,/]|\s)
# (/|\s)Strongtalk([,/]|\s)
# (/|\s)Snap!([,/]|\s)
# (/|\s)SNOBOL([,/]|\s)
# (/|\s)Snowball([,/]|\s)
# (/|\s)SOL([,/]|\s)
# (/|\s)Solidity([,/]|\s)
# (/|\s)SOPHAEROS([,/]|\s)
# (/|\s)Source([,/]|\s)
# (/|\s)SPARK([,/]|\s)
# (/|\s)Speakeasy([,/]|\s)
# (/|\s)Speedcode([,/]|\s)
# (/|\s)SPIN([,/]|\s)
# (/|\s)SP/k([,/]|\s)
# (/|\s)SPS([,/]|\s)
# (/|\s)SQL([,/]|\s)
# (/|\s)SQR([,/]|\s)
# (/|\s)Squeak([,/]|\s)
# (/|\s)Squirrel([,/]|\s)
# (/|\s)SR([,/]|\s)
# (/|\s)S/SL([,/]|\s)
# (/|\s)Starlogo([,/]|\s)
# (/|\s)Strand([,/]|\s)
# (/|\s)Stata([,/]|\s)
# (/|\s)Stateflow([,/]|\s)
# (/|\s)Subtext([,/]|\s)
# (/|\s)SBL([,/]|\s)
# (/|\s)SuperCollider([,/]|\s)
# (/|\s)SuperTalk([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)SYMPL([,/]|\s)
# (/|\s)SystemVerilog([,/]|\s)
# (/|\s)T([,/]|\s)
# (/|\s)TACL([,/]|\s)
# (/|\s)TACPOL([,/]|\s)
# (/|\s)TADS([,/]|\s)
# (/|\s)TAL([,/]|\s)
# (/|\s)Tcl([,/]|\s)
# (/|\s)Tea([,/]|\s)
# (/|\s)TECO([,/]|\s)
# (/|\s)TELCOMP([,/]|\s)
# (/|\s)TeX([,/]|\s)
# (/|\s)TEX([,/]|\s)
# (/|\s)TIE([,/]|\s)
# (/|\s)TMG([,/]|\s)
# (/|\s)Tom([,/]|\s)
# (/|\s)Toi([,/]|\s)
# (/|\s)Topspeed([,/]|\s)
# (/|\s)TPU([,/]|\s)
# (/|\s)Trac([,/]|\s)
# (/|\s)TTM([,/]|\s)
# (/|\s)T\-SQL([,/]|\s)
# (/|\s)Transcript([,/]|\s)
# (/|\s)TTCN([,/]|\s)
# (/|\s)Turing([,/]|\s)
# (/|\s)TUTOR([,/]|\s)
# (/|\s)TXL([,/]|\s)
# (/|\s)TypeScript([,/]|\s)
# (/|\s)Tynker([,/]|\s)
# (/|\s)Ubercode([,/]|\s)
# (/|\s)UCSD\ Pascal([,/]|\s)
# (/|\s)Umple([,/]|\s)
# (/|\s)Unicon([,/]|\s)
# (/|\s)Uniface([,/]|\s)
# (/|\s)UNITY([,/]|\s)
# (/|\s)Unix\ shell([,/]|\s)
# (/|\s)UnrealScript([,/]|\s)
# (/|\s)Vala([,/]|\s)
# (/|\s)Verilog([,/]|\s)
# (/|\s)VHDL([,/]|\s)
# (/|\s)Vim\ script([,/]|\s)
# (/|\s)Viper([,/]|\s)
# (/|\s)Visual\ DataFlex([,/]|\s)
# (/|\s)Visual\ DialogScript([,/]|\s)
# (/|\s)Visual\ FoxPro([,/]|\s)
# (/|\s)Visual\ J\+\+([,/]|\s)
# (/|\s)Visual\ LISP([,/]|\s)
# (/|\s)Visual\ Objects([,/]|\s)
# (/|\s)Visual\ Prolog([,/]|\s)
# (/|\s)WATFIV,\ WATFOR([,/]|\s)
# (/|\s)WebAssembly([,/]|\s)
# (/|\s)WebDNA([,/]|\s)
# (/|\s)Whiley([,/]|\s)
# (/|\s)Winbatch([,/]|\s)
# (/|\s)Wolfram\ Language([,/]|\s)
# (/|\s)Wyvern([,/]|\s)
# (/|\s)X\+\+([,/]|\s)
# (/|\s)X10([,/]|\s)
# (/|\s)xBase([,/]|\s)
# (/|\s)xBase\+\+([,/]|\s)
# (/|\s)XBL([,/]|\s)
# (/|\s)XC([,/]|\s)
# (/|\s)xHarbour([,/]|\s)
# (/|\s)XL([,/]|\s)
# (/|\s)Xojo([,/]|\s)
# (/|\s)XOTcl([,/]|\s)
# (/|\s)Xod([,/]|\s)
# (/|\s)XPL([,/]|\s)
# (/|\s)XPL0([,/]|\s)
# (/|\s)XQuery([,/]|\s)
# (/|\s)XSB([,/]|\s)
# (/|\s)XSharp([,/]|\s)
# (/|\s)XSLT([,/]|\s)
# (/|\s)Xtend([,/]|\s)
# (/|\s)Yorick([,/]|\s)
# (/|\s)YQL([,/]|\s)
# (/|\s)Yoix([,/]|\s)
# (/|\s)YUI([,/]|\s)
# (/|\s)Z\ notation([,/]|\s)
# (/|\s)Zebra,\ ZPL,\ ZPL2([,/]|\s)
# (/|\s)Zeno([,/]|\s)
# (/|\s)ZetaLisp([,/]|\s)
# (/|\s)Zig([,/]|\s)
# (/|\s)ZOPL([,/]|\s)
# (/|\s)ZPL([,/]|\s)
# (/|\s)Z\+\+([,/]|\s)
# (/|\s)A\.NET([,/]|\s)
# (/|\s)A\-0\ System([,/]|\s)
# (/|\s)A\+([,/]|\s)
# (/|\s)ABAP([,/]|\s)
# (/|\s)ABC([,/]|\s)
# (/|\s)ABC\ ALGOL([,/]|\s)
# (/|\s)ACC([,/]|\s)
# (/|\s)Accent([,/]|\s)
# (/|\s)Ace\ DASL([,/]|\s)
# (/|\s)Action!([,/]|\s)
# (/|\s)ActionScript([,/]|\s)
# (/|\s)Actor([,/]|\s)
# (/|\s)Ada([,/]|\s)
# (/|\s)Adenine([,/]|\s)
# (/|\s)AdvPL([,/]|\s)
# (/|\s)Agda([,/]|\s)
# (/|\s)Agilent\ VEE([,/]|\s)
# (/|\s)Agora([,/]|\s)
# (/|\s)AIMMS([,/]|\s)
# (/|\s)Aldor([,/]|\s)
# (/|\s)Alef([,/]|\s)
# (/|\s)ALF([,/]|\s)
# (/|\s)ALGOL\ 58([,/]|\s)
# (/|\s)ALGOL\ 60([,/]|\s)
# (/|\s)ALGOL\ 68([,/]|\s)
# (/|\s)ALGOL\ W([,/]|\s)
# (/|\s)Alice([,/]|\s)
# (/|\s)Alma\-0([,/]|\s)
# (/|\s)AmbientTalk([,/]|\s)
# (/|\s)Amiga\ E([,/]|\s)
# (/|\s)AMOS([,/]|\s)
# (/|\s)AMPL([,/]|\s)
# (/|\s)AngelScript([,/]|\s)
# (/|\s)Apache\ Pig\ latin([,/]|\s)
# (/|\s)Apex([,/]|\s)
# (/|\s)APL([,/]|\s)
# (/|\s)App\ Inventor\ for\ Android's\ visual\ block\ language([,/]|\s)
# (/|\s)AppleScript([,/]|\s)
# (/|\s)APT([,/]|\s)
# (/|\s)Arc([,/]|\s)
# (/|\s)ARexx([,/]|\s)
# (/|\s)Argus([,/]|\s)
# (/|\s)Assembly\ language([,/]|\s)
# (/|\s)AutoIt([,/]|\s)
# (/|\s)AutoLISP\ /\ Visual\ LISP([,/]|\s)
# (/|\s)Averest([,/]|\s)
# (/|\s)AWK([,/]|\s)
# (/|\s)Axum([,/]|\s)
# (/|\s)B([,/]|\s)
# (/|\s)Babbage([,/]|\s)
# (/|\s)Ballerina([,/]|\s)
# (/|\s)Bash([,/]|\s)
# (/|\s)BASIC([,/]|\s)
# (/|\s)Batch\ file([,/]|\s)
# (/|\s)bc([,/]|\s)
# (/|\s)BCPL([,/]|\s)
# (/|\s)BeanShell([,/]|\s)
# (/|\s)Bertrand([,/]|\s)
# (/|\s)BETA([,/]|\s)
# (/|\s)BLISS([,/]|\s)
# (/|\s)Blockly([,/]|\s)
# (/|\s)BlooP([,/]|\s)
# (/|\s)Boo([,/]|\s)
# (/|\s)Boomerang([,/]|\s)
# (/|\s)Bosque([,/]|\s)
# (/|\s)C\ –\ ISO/IEC\ 9899([,/]|\s)
# (/|\s)C\-\-([,/]|\s)
# (/|\s)C\+\+([,/]|\s)
# (/|\s)C\*([,/]|\s)
# (/|\s)C\#([,/]|\s)
# (/|\s)C/AL([,/]|\s)
# (/|\s)Caché\ ObjectScript([,/]|\s)
# (/|\s)C\ Shell([,/]|\s)
# (/|\s)Caml([,/]|\s)
# (/|\s)Cayenne([,/]|\s)
# (/|\s)CDuce([,/]|\s)
# (/|\s)Cecil([,/]|\s)
# (/|\s)Cesil([,/]|\s)
# (/|\s)Céu([,/]|\s)
# (/|\s)Ceylon([,/]|\s)
# (/|\s)CFEngine([,/]|\s)
# (/|\s)Cg([,/]|\s)
# (/|\s)Ch([,/]|\s)
# (/|\s)Chapel([,/]|\s)
# (/|\s)Charm([,/]|\s)
# (/|\s)CHILL([,/]|\s)
# (/|\s)CHIP\-8([,/]|\s)
# (/|\s)ChucK([,/]|\s)
# (/|\s)Cilk([,/]|\s)
# (/|\s)CL([,/]|\s)
# (/|\s)Claire([,/]|\s)
# (/|\s)Clarion([,/]|\s)
# (/|\s)Clean([,/]|\s)
# (/|\s)Clipper([,/]|\s)
# (/|\s)CLIPS([,/]|\s)
# (/|\s)CLIST([,/]|\s)
# (/|\s)Clojure([,/]|\s)
# (/|\s)CLU([,/]|\s)
# (/|\s)CMS\-2([,/]|\s)
# (/|\s)COBOL\ –\ ISO/IEC\ 1989([,/]|\s)
# (/|\s)CobolScript\ –\ COBOL\ Scripting\ language([,/]|\s)
# (/|\s)Cobra([,/]|\s)
# (/|\s)CoffeeScript([,/]|\s)
# (/|\s)ColdFusion([,/]|\s)
# (/|\s)COMAL([,/]|\s)
# (/|\s)Combined\ Programming\ Language([,/]|\s)
# (/|\s)COMIT([,/]|\s)
# (/|\s)Common\ Intermediate\ Language([,/]|\s)
# (/|\s)Common\ Lisp([,/]|\s)
# (/|\s)COMPASS([,/]|\s)
# (/|\s)Component\ Pascal([,/]|\s)
# (/|\s)Constraint\ Handling\ Rules([,/]|\s)
# (/|\s)COMTRAN([,/]|\s)
# (/|\s)Cool([,/]|\s)
# (/|\s)Coq([,/]|\s)
# (/|\s)Coral\ 66([,/]|\s)
# (/|\s)CorVision([,/]|\s)
# (/|\s)COWSEL([,/]|\s)
# (/|\s)CPL([,/]|\s)
# (/|\s)Cryptol([,/]|\s)
# (/|\s)Crystal([,/]|\s)
# (/|\s)Csound([,/]|\s)
# (/|\s)Cuneiform([,/]|\s)
# (/|\s)Curl([,/]|\s)
# (/|\s)Curry([,/]|\s)
# (/|\s)Cybil([,/]|\s)
# (/|\s)Cyclone([,/]|\s)
# (/|\s)Cypher\ Query\ Language([,/]|\s)
# (/|\s)Cython([,/]|\s)
# (/|\s)CEEMAC([,/]|\s)
# (/|\s)D([,/]|\s)
# (/|\s)Dart([,/]|\s)
# (/|\s)Darwin([,/]|\s)
# (/|\s)DataFlex([,/]|\s)
# (/|\s)Datalog([,/]|\s)
# (/|\s)DATATRIEVE([,/]|\s)
# (/|\s)dBase([,/]|\s)
# (/|\s)dc([,/]|\s)
# (/|\s)DCL([,/]|\s)
# (/|\s)Delphi([,/]|\s)
# (/|\s)DinkC([,/]|\s)
# (/|\s)DIBOL([,/]|\s)
# (/|\s)Dog([,/]|\s)
# (/|\s)Draco([,/]|\s)
# (/|\s)DRAKON([,/]|\s)
# (/|\s)Dylan([,/]|\s)
# (/|\s)DYNAMO([,/]|\s)
# (/|\s)DAX([,/]|\s)
# (/|\s)E([,/]|\s)
# (/|\s)Ease([,/]|\s)
# (/|\s)Easy\ PL/I([,/]|\s)
# (/|\s)EASYTRIEVE\ PLUS([,/]|\s)
# (/|\s)eC([,/]|\s)
# (/|\s)ECMAScript([,/]|\s)
# (/|\s)Edinburgh\ IMP([,/]|\s)
# (/|\s)EGL([,/]|\s)
# (/|\s)Eiffel([,/]|\s)
# (/|\s)ELAN([,/]|\s)
# (/|\s)Elixir([,/]|\s)
# (/|\s)Elm([,/]|\s)
# (/|\s)Emacs\ Lisp([,/]|\s)
# (/|\s)Emerald([,/]|\s)
# (/|\s)Epigram([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)Erlang([,/]|\s)
# (/|\s)es([,/]|\s)
# (/|\s)Escher([,/]|\s)
# (/|\s)ESPOL([,/]|\s)
# (/|\s)Esterel([,/]|\s)
# (/|\s)Etoys([,/]|\s)
# (/|\s)Euclid([,/]|\s)
# (/|\s)Euler([,/]|\s)
# (/|\s)Euphoria([,/]|\s)
# (/|\s)EusLisp\ Robot\ Programming\ Language([,/]|\s)
# (/|\s)CMS\ EXEC([,/]|\s)
# (/|\s)EXEC\ 2([,/]|\s)
# (/|\s)Executable\ UML([,/]|\s)
# (/|\s)Ezhil([,/]|\s)
# (/|\s)F([,/]|\s)
# (/|\s)F\#([,/]|\s)
# (/|\s)F\*([,/]|\s)
# (/|\s)Factor([,/]|\s)
# (/|\s)Fantom([,/]|\s)
# (/|\s)FAUST([,/]|\s)
# (/|\s)FFP([,/]|\s)
# (/|\s)fish([,/]|\s)
# (/|\s)Fjölnir([,/]|\s)
# (/|\s)FL([,/]|\s)
# (/|\s)Flavors([,/]|\s)
# (/|\s)Flex([,/]|\s)
# (/|\s)Flix([,/]|\s)
# (/|\s)FlooP([,/]|\s)
# (/|\s)FLOW\-MASTIC([,/]|\s)
# (/|\s)FOCAL([,/]|\s)
# (/|\s)FOCUS([,/]|\s)
# (/|\s)FOIL([,/]|\s)
# (/|\s)FORMAC([,/]|\s)
# (/|\s)@Formula([,/]|\s)
# (/|\s)Forth([,/]|\s)
# (/|\s)Fortran\ –\ ISO/IEC\ 1539([,/]|\s)
# (/|\s)Fortress([,/]|\s)
# (/|\s)FP([,/]|\s)
# (/|\s)Franz\ Lisp([,/]|\s)
# (/|\s)Futhark([,/]|\s)
# (/|\s)F\-Script([,/]|\s)
# (/|\s)Game\ Maker\ Language([,/]|\s)
# (/|\s)GameMonkey\ Script([,/]|\s)
# (/|\s)GAMS([,/]|\s)
# (/|\s)GAP([,/]|\s)
# (/|\s)G\-code([,/]|\s)
# (/|\s)GDScript([,/]|\s)
# (/|\s)Genie([,/]|\s)
# (/|\s)GDL([,/]|\s)
# (/|\s)GEORGE([,/]|\s)
# (/|\s)GLSL([,/]|\s)
# (/|\s)GNU\ E([,/]|\s)
# (/|\s)GNU\ Guile([,/]|\s)
# (/|\s)Go([,/]|\s)
# (/|\s)Go!([,/]|\s)
# (/|\s)GOAL([,/]|\s)
# (/|\s)Gödel([,/]|\s)
# (/|\s)Golo([,/]|\s)
# (/|\s)GOM([,/]|\s)
# (/|\s)Google\ Apps\ Script([,/]|\s)
# (/|\s)Gosu([,/]|\s)
# (/|\s)GOTRAN([,/]|\s)
# (/|\s)GPSS([,/]|\s)
# (/|\s)GraphTalk([,/]|\s)
# (/|\s)GRASS([,/]|\s)
# (/|\s)Grasshopper([,/]|\s)
# (/|\s)Groovy([,/]|\s)
# (/|\s)Hack([,/]|\s)
# (/|\s)HAGGIS([,/]|\s)
# (/|\s)HAL/S([,/]|\s)
# (/|\s)Halide([,/]|\s)
# (/|\s)Hamilton\ C\ shell([,/]|\s)
# (/|\s)Harbour([,/]|\s)
# (/|\s)Hartmann\ pipelines([,/]|\s)
# (/|\s)Haskell([,/]|\s)
# (/|\s)Haxe([,/]|\s)
# (/|\s)Hermes([,/]|\s)
# (/|\s)High\ Level\ Assembly([,/]|\s)
# (/|\s)HLSL([,/]|\s)
# (/|\s)Hollywood([,/]|\s)
# (/|\s)HolyC([,/]|\s)
# (/|\s)Hop([,/]|\s)
# (/|\s)Hopscotch([,/]|\s)
# (/|\s)Hope([,/]|\s)
# (/|\s)Hugo([,/]|\s)
# (/|\s)Hume([,/]|\s)
# (/|\s)HyperTalk([,/]|\s)
# (/|\s)Io([,/]|\s)
# (/|\s)Icon([,/]|\s)
# (/|\s)IBM\ Basic\ assembly\ language([,/]|\s)
# (/|\s)IBM\ HAScript([,/]|\s)
# (/|\s)IBM\ Informix\-4GL([,/]|\s)
# (/|\s)IBM\ RPG([,/]|\s)
# (/|\s)IDL([,/]|\s)
# (/|\s)Idris([,/]|\s)
# (/|\s)Inform([,/]|\s)
# (/|\s)J([,/]|\s)
# (/|\s)J\#([,/]|\s)
# (/|\s)J\+\+([,/]|\s)
# (/|\s)JADE([,/]|\s)
# (/|\s)Jai([,/]|\s)
# (/|\s)JAL([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)JASS([,/]|\s)
# (/|\s)Java([,/]|\s)
# (/|\s)JavaFX\ Script([,/]|\s)
# (/|\s)JavaScript([,/]|\s)
# (/|\s)Jess([,/]|\s)
# (/|\s)JCL([,/]|\s)
# (/|\s)JEAN([,/]|\s)
# (/|\s)Join\ Java([,/]|\s)
# (/|\s)JOSS([,/]|\s)
# (/|\s)Joule([,/]|\s)
# (/|\s)JOVIAL([,/]|\s)
# (/|\s)Joy([,/]|\s)
# (/|\s)JScript([,/]|\s)
# (/|\s)JScript\ \.NET([,/]|\s)
# (/|\s)Julia([,/]|\s)
# (/|\s)Jython([,/]|\s)
# (/|\s)K([,/]|\s)
# (/|\s)Kaleidoscope([,/]|\s)
# (/|\s)Karel([,/]|\s)
# (/|\s)KEE([,/]|\s)
# (/|\s)Kixtart([,/]|\s)
# (/|\s)Klerer\-May\ System([,/]|\s)
# (/|\s)KIF([,/]|\s)
# (/|\s)Kojo([,/]|\s)
# (/|\s)Kotlin([,/]|\s)
# (/|\s)KRC([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRYPTON([,/]|\s)
# (/|\s)KornShell([,/]|\s)
# (/|\s)Kodu([,/]|\s)
# (/|\s)Kv([,/]|\s)
# (/|\s)LabVIEW([,/]|\s)
# (/|\s)Ladder([,/]|\s)
# (/|\s)LANSA([,/]|\s)
# (/|\s)Lasso([,/]|\s)
# (/|\s)Lava([,/]|\s)
# (/|\s)LC\-3([,/]|\s)
# (/|\s)Lean([,/]|\s)
# (/|\s)Legoscript([,/]|\s)
# (/|\s)LIL([,/]|\s)
# (/|\s)LilyPond([,/]|\s)
# (/|\s)Limbo([,/]|\s)
# (/|\s)Limnor([,/]|\s)
# (/|\s)LINC([,/]|\s)
# (/|\s)Lingo([,/]|\s)
# (/|\s)LINQ([,/]|\s)
# (/|\s)LIS([,/]|\s)
# (/|\s)LISA([,/]|\s)
# (/|\s)Language\ H([,/]|\s)
# (/|\s)Lisp\ –\ ISO/IEC\ 13816([,/]|\s)
# (/|\s)Lite\-C([,/]|\s)
# (/|\s)Lithe([,/]|\s)
# (/|\s)Little\ b([,/]|\s)
# (/|\s)LLL([,/]|\s)
# (/|\s)Logo([,/]|\s)
# (/|\s)Logtalk([,/]|\s)
# (/|\s)LotusScript([,/]|\s)
# (/|\s)LPC([,/]|\s)
# (/|\s)LSE([,/]|\s)
# (/|\s)LSL([,/]|\s)
# (/|\s)LiveCode([,/]|\s)
# (/|\s)LiveScript([,/]|\s)
# (/|\s)Lua([,/]|\s)
# (/|\s)Lucid([,/]|\s)
# (/|\s)Lustre([,/]|\s)
# (/|\s)LYaPAS([,/]|\s)
# (/|\s)Lynx([,/]|\s)
# (/|\s)M2001([,/]|\s)
# (/|\s)M4([,/]|\s)
# (/|\s)M\#([,/]|\s)
# (/|\s)Machine\ code([,/]|\s)
# (/|\s)MAD([,/]|\s)
# (/|\s)MAD/I([,/]|\s)
# (/|\s)Magik([,/]|\s)
# (/|\s)Magma([,/]|\s)
# (/|\s)Máni([,/]|\s)
# (/|\s)Maple([,/]|\s)
# (/|\s)MAPPER([,/]|\s)
# (/|\s)MARK\-IV([,/]|\s)
# (/|\s)Mary([,/]|\s)
# (/|\s)MATLAB([,/]|\s)
# (/|\s)MASM\ Microsoft\ Assembly\ x86([,/]|\s)
# (/|\s)MATH\-MATIC([,/]|\s)
# (/|\s)Maude\ system([,/]|\s)
# (/|\s)Maxima([,/]|\s)
# (/|\s)Max([,/]|\s)
# (/|\s)MaxScript\ internal\ language\ 3D\ Studio\ Max([,/]|\s)
# (/|\s)Maya([,/]|\s)
# (/|\s)MDL([,/]|\s)
# (/|\s)Mercury([,/]|\s)
# (/|\s)Mesa([,/]|\s)
# (/|\s)MHEG\-5([,/]|\s)
# (/|\s)Microcode([,/]|\s)
# (/|\s)MicroScript([,/]|\s)
# (/|\s)Microsoft\ Power\ Fx([,/]|\s)
# (/|\s)MIIS([,/]|\s)
# (/|\s)Milk([,/]|\s)
# (/|\s)MIMIC([,/]|\s)
# (/|\s)Mirah([,/]|\s)
# (/|\s)Miranda([,/]|\s)
# (/|\s)MIVA\ Script([,/]|\s)
# (/|\s)ML([,/]|\s)
# (/|\s)Model\ 204([,/]|\s)
# (/|\s)Modelica([,/]|\s)
# (/|\s)Modula([,/]|\s)
# (/|\s)Modula\-2([,/]|\s)
# (/|\s)Modula\-3([,/]|\s)
# (/|\s)Mohol([,/]|\s)
# (/|\s)MOO([,/]|\s)
# (/|\s)Mortran([,/]|\s)
# (/|\s)Mouse([,/]|\s)
# (/|\s)MPD([,/]|\s)
# (/|\s)MSL([,/]|\s)
# (/|\s)MUMPS([,/]|\s)
# (/|\s)MuPAD([,/]|\s)
# (/|\s)Mutan([,/]|\s)
# (/|\s)Mystic\ Programming\ Language([,/]|\s)
# (/|\s)NASM([,/]|\s)
# (/|\s)Napier88([,/]|\s)
# (/|\s)Neko([,/]|\s)
# (/|\s)Nemerle([,/]|\s)
# (/|\s)NESL([,/]|\s)
# (/|\s)Net\.Data([,/]|\s)
# (/|\s)NetLogo([,/]|\s)
# (/|\s)NetRexx([,/]|\s)
# (/|\s)NewLISP([,/]|\s)
# (/|\s)NEWP([,/]|\s)
# (/|\s)Newspeak([,/]|\s)
# (/|\s)NewtonScript([,/]|\s)
# (/|\s)Nial([,/]|\s)
# (/|\s)Nickle([,/]|\s)
# (/|\s)Nim([,/]|\s)
# (/|\s)Nix([,/]|\s)
# (/|\s)NPL([,/]|\s)
# (/|\s)Not\ eXactly\ C([,/]|\s)
# (/|\s)Not\ Quite\ C([,/]|\s)
# (/|\s)NSIS([,/]|\s)
# (/|\s)Nu([,/]|\s)
# (/|\s)NWScript([,/]|\s)
# (/|\s)NXT\-G([,/]|\s)
# (/|\s)o:XML([,/]|\s)
# (/|\s)Oak([,/]|\s)
# (/|\s)Oberon([,/]|\s)
# (/|\s)OBJ2([,/]|\s)
# (/|\s)Object\ Lisp([,/]|\s)
# (/|\s)ObjectLOGO([,/]|\s)
# (/|\s)Object\ REXX([,/]|\s)
# (/|\s)Object\ Pascal([,/]|\s)
# (/|\s)Objective\-C([,/]|\s)
# (/|\s)Objective\-J([,/]|\s)
# (/|\s)Obliq([,/]|\s)
# (/|\s)OCaml([,/]|\s)
# (/|\s)occam([,/]|\s)
# (/|\s)occam\-π([,/]|\s)
# (/|\s)Octave([,/]|\s)
# (/|\s)OmniMark([,/]|\s)
# (/|\s)Opa([,/]|\s)
# (/|\s)Opal([,/]|\s)
# (/|\s)OpenCL([,/]|\s)
# (/|\s)OpenEdge\ ABL([,/]|\s)
# (/|\s)OPL([,/]|\s)
# (/|\s)OpenVera([,/]|\s)
# (/|\s)OPS5([,/]|\s)
# (/|\s)OptimJ([,/]|\s)
# (/|\s)Orc([,/]|\s)
# (/|\s)ORCA/Modula\-2([,/]|\s)
# (/|\s)Oriel([,/]|\s)
# (/|\s)Orwell([,/]|\s)
# (/|\s)Oxygene([,/]|\s)
# (/|\s)Oz([,/]|\s)
# (/|\s)P([,/]|\s)
# (/|\s)P4([,/]|\s)
# (/|\s)P′′([,/]|\s)
# (/|\s)ParaSail([,/]|\s)
# (/|\s)PARI/GP([,/]|\s)
# (/|\s)Pascal\ –\ ISO\ 7185([,/]|\s)
# (/|\s)Pascal\ Script([,/]|\s)
# (/|\s)PCASTL([,/]|\s)
# (/|\s)PCF([,/]|\s)
# (/|\s)PEARL([,/]|\s)
# (/|\s)PeopleCode([,/]|\s)
# (/|\s)Perl([,/]|\s)
# (/|\s)PDL([,/]|\s)
# (/|\s)Pharo([,/]|\s)
# (/|\s)PHP([,/]|\s)
# (/|\s)Pico([,/]|\s)
# (/|\s)Picolisp([,/]|\s)
# (/|\s)Pict([,/]|\s)
# (/|\s)Pike([,/]|\s)
# (/|\s)PILOT([,/]|\s)
# (/|\s)Pipelines([,/]|\s)
# (/|\s)Pizza([,/]|\s)
# (/|\s)PL\-11([,/]|\s)
# (/|\s)PL/0([,/]|\s)
# (/|\s)PL/B([,/]|\s)
# (/|\s)PL/C([,/]|\s)
# (/|\s)PL/I\ –\ ISO\ 6160([,/]|\s)
# (/|\s)PL/M([,/]|\s)
# (/|\s)PL/P([,/]|\s)
# (/|\s)PL/SQL([,/]|\s)
# (/|\s)PL360([,/]|\s)
# (/|\s)PLANC([,/]|\s)
# (/|\s)Plankalkül([,/]|\s)
# (/|\s)Planner([,/]|\s)
# (/|\s)PLEX([,/]|\s)
# (/|\s)PLEXIL([,/]|\s)
# (/|\s)Plus([,/]|\s)
# (/|\s)POP\-11([,/]|\s)
# (/|\s)POP\-2([,/]|\s)
# (/|\s)PostScript([,/]|\s)
# (/|\s)PortablE([,/]|\s)
# (/|\s)POV\-Ray\ SDL([,/]|\s)
# (/|\s)Powerhouse([,/]|\s)
# (/|\s)PowerBuilder\ –\ 4GL\ GUI\ application\ generator\ from\ Sybase([,/]|\s)
# (/|\s)PowerShell([,/]|\s)
# (/|\s)PPL([,/]|\s)
# (/|\s)Processing([,/]|\s)
# (/|\s)Processing\.js([,/]|\s)
# (/|\s)Prograph([,/]|\s)
# (/|\s)PROIV([,/]|\s)
# (/|\s)Project\ Verona([,/]|\s)
# (/|\s)Prolog([,/]|\s)
# (/|\s)PROMAL([,/]|\s)
# (/|\s)Promela([,/]|\s)
# (/|\s)PROSE\ modeling\ language([,/]|\s)
# (/|\s)PROTEL([,/]|\s)
# (/|\s)ProvideX([,/]|\s)
# (/|\s)Pro\*C([,/]|\s)
# (/|\s)Pure([,/]|\s)
# (/|\s)Pure\ Data([,/]|\s)
# (/|\s)PureScript([,/]|\s)
# (/|\s)Python([,/]|\s)
# (/|\s)Q([,/]|\s)
# (/|\s)Q\#([,/]|\s)
# (/|\s)Qalb([,/]|\s)
# (/|\s)Quantum\ Computation\ Language([,/]|\s)
# (/|\s)QtScript([,/]|\s)
# (/|\s)QuakeC([,/]|\s)
# (/|\s)QPL([,/]|\s)
# (/|\s)\.QL([,/]|\s)
# (/|\s)R([,/]|\s)
# (/|\s)R\+\+([,/]|\s)
# (/|\s)Racket([,/]|\s)
# (/|\s)Raku([,/]|\s)
# (/|\s)RAPID([,/]|\s)
# (/|\s)Rapira([,/]|\s)
# (/|\s)Ratfiv([,/]|\s)
# (/|\s)Ratfor([,/]|\s)
# (/|\s)rc([,/]|\s)
# (/|\s)Reason([,/]|\s)
# (/|\s)REBOL([,/]|\s)
# (/|\s)Red([,/]|\s)
# (/|\s)Redcode([,/]|\s)
# (/|\s)REFAL([,/]|\s)
# (/|\s)REXX([,/]|\s)
# (/|\s)Rlab([,/]|\s)
# (/|\s)ROOP([,/]|\s)
# (/|\s)RPG([,/]|\s)
# (/|\s)RPL([,/]|\s)
# (/|\s)RSL([,/]|\s)
# (/|\s)RTL/2([,/]|\s)
# (/|\s)Ruby([,/]|\s)
# (/|\s)Rust([,/]|\s)
# (/|\s)S([,/]|\s)
# (/|\s)S2([,/]|\s)
# (/|\s)S3([,/]|\s)
# (/|\s)S\-Lang([,/]|\s)
# (/|\s)S\-PLUS([,/]|\s)
# (/|\s)SA\-C([,/]|\s)
# (/|\s)SabreTalk([,/]|\s)
# (/|\s)SAIL([,/]|\s)
# (/|\s)SAS([,/]|\s)
# (/|\s)SASL([,/]|\s)
# (/|\s)Sather([,/]|\s)
# (/|\s)Sawzall([,/]|\s)
# (/|\s)Scala([,/]|\s)
# (/|\s)Scheme([,/]|\s)
# (/|\s)Scilab([,/]|\s)
# (/|\s)Scratch([,/]|\s)
# (/|\s)Script\.NET([,/]|\s)
# (/|\s)Sed([,/]|\s)
# (/|\s)Seed7([,/]|\s)
# (/|\s)Self([,/]|\s)
# (/|\s)SenseTalk([,/]|\s)
# (/|\s)SequenceL([,/]|\s)
# (/|\s)Serpent([,/]|\s)
# (/|\s)SETL([,/]|\s)
# (/|\s)SIMPOL([,/]|\s)
# (/|\s)SIGNAL([,/]|\s)
# (/|\s)SiMPLE([,/]|\s)
# (/|\s)SIMSCRIPT([,/]|\s)
# (/|\s)Simula([,/]|\s)
# (/|\s)Simulink([,/]|\s)
# (/|\s)Singularity([,/]|\s)
# (/|\s)SISAL([,/]|\s)
# (/|\s)SLIP([,/]|\s)
# (/|\s)SMALL([,/]|\s)
# (/|\s)Smalltalk([,/]|\s)
# (/|\s)SML([,/]|\s)
# (/|\s)Strongtalk([,/]|\s)
# (/|\s)Snap!([,/]|\s)
# (/|\s)SNOBOL([,/]|\s)
# (/|\s)Snowball([,/]|\s)
# (/|\s)SOL([,/]|\s)
# (/|\s)Solidity([,/]|\s)
# (/|\s)SOPHAEROS([,/]|\s)
# (/|\s)Source([,/]|\s)
# (/|\s)SPARK([,/]|\s)
# (/|\s)Speakeasy([,/]|\s)
# (/|\s)Speedcode([,/]|\s)
# (/|\s)SPIN([,/]|\s)
# (/|\s)SP/k([,/]|\s)
# (/|\s)SPS([,/]|\s)
# (/|\s)SQL([,/]|\s)
# (/|\s)SQR([,/]|\s)
# (/|\s)Squeak([,/]|\s)
# (/|\s)Squirrel([,/]|\s)
# (/|\s)SR([,/]|\s)
# (/|\s)S/SL([,/]|\s)
# (/|\s)Starlogo([,/]|\s)
# (/|\s)Strand([,/]|\s)
# (/|\s)Stata([,/]|\s)
# (/|\s)Stateflow([,/]|\s)
# (/|\s)Subtext([,/]|\s)
# (/|\s)SBL([,/]|\s)
# (/|\s)SuperCollider([,/]|\s)
# (/|\s)SuperTalk([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)SYMPL([,/]|\s)
# (/|\s)SystemVerilog([,/]|\s)
# (/|\s)T([,/]|\s)
# (/|\s)TACL([,/]|\s)
# (/|\s)TACPOL([,/]|\s)
# (/|\s)TADS([,/]|\s)
# (/|\s)TAL([,/]|\s)
# (/|\s)Tcl([,/]|\s)
# (/|\s)Tea([,/]|\s)
# (/|\s)TECO([,/]|\s)
# (/|\s)TELCOMP([,/]|\s)
# (/|\s)TeX([,/]|\s)
# (/|\s)TEX([,/]|\s)
# (/|\s)TIE([,/]|\s)
# (/|\s)TMG([,/]|\s)
# (/|\s)Tom([,/]|\s)
# (/|\s)Toi([,/]|\s)
# (/|\s)Topspeed([,/]|\s)
# (/|\s)TPU([,/]|\s)
# (/|\s)Trac([,/]|\s)
# (/|\s)TTM([,/]|\s)
# (/|\s)T\-SQL([,/]|\s)
# (/|\s)Transcript([,/]|\s)
# (/|\s)TTCN([,/]|\s)
# (/|\s)Turing([,/]|\s)
# (/|\s)TUTOR([,/]|\s)
# (/|\s)TXL([,/]|\s)
# (/|\s)TypeScript([,/]|\s)
# (/|\s)Tynker([,/]|\s)
# (/|\s)Ubercode([,/]|\s)
# (/|\s)UCSD\ Pascal([,/]|\s)
# (/|\s)Umple([,/]|\s)
# (/|\s)Unicon([,/]|\s)
# (/|\s)Uniface([,/]|\s)
# (/|\s)UNITY([,/]|\s)
# (/|\s)Unix\ shell([,/]|\s)
# (/|\s)UnrealScript([,/]|\s)
# (/|\s)Vala([,/]|\s)
# (/|\s)Verilog([,/]|\s)
# (/|\s)VHDL([,/]|\s)
# (/|\s)Vim\ script([,/]|\s)
# (/|\s)Viper([,/]|\s)
# (/|\s)Visual\ DataFlex([,/]|\s)
# (/|\s)Visual\ DialogScript([,/]|\s)
# (/|\s)Visual\ FoxPro([,/]|\s)
# (/|\s)Visual\ J\+\+([,/]|\s)
# (/|\s)Visual\ LISP([,/]|\s)
# (/|\s)Visual\ Objects([,/]|\s)
# (/|\s)Visual\ Prolog([,/]|\s)
# (/|\s)WATFIV,\ WATFOR([,/]|\s)
# (/|\s)WebAssembly([,/]|\s)
# (/|\s)WebDNA([,/]|\s)
# (/|\s)Whiley([,/]|\s)
# (/|\s)Winbatch([,/]|\s)
# (/|\s)Wolfram\ Language([,/]|\s)
# (/|\s)Wyvern([,/]|\s)
# (/|\s)X\+\+([,/]|\s)
# (/|\s)X10([,/]|\s)
# (/|\s)xBase([,/]|\s)
# (/|\s)xBase\+\+([,/]|\s)
# (/|\s)XBL([,/]|\s)
# (/|\s)XC([,/]|\s)
# (/|\s)xHarbour([,/]|\s)
# (/|\s)XL([,/]|\s)
# (/|\s)Xojo([,/]|\s)
# (/|\s)XOTcl([,/]|\s)
# (/|\s)Xod([,/]|\s)
# (/|\s)XPL([,/]|\s)
# (/|\s)XPL0([,/]|\s)
# (/|\s)XQuery([,/]|\s)
# (/|\s)XSB([,/]|\s)
# (/|\s)XSharp([,/]|\s)
# (/|\s)XSLT([,/]|\s)
# (/|\s)Xtend([,/]|\s)
# (/|\s)Yorick([,/]|\s)
# (/|\s)YQL([,/]|\s)
# (/|\s)Yoix([,/]|\s)
# (/|\s)YUI([,/]|\s)
# (/|\s)Z\ notation([,/]|\s)
# (/|\s)Zebra,\ ZPL,\ ZPL2([,/]|\s)
# (/|\s)Zeno([,/]|\s)
# (/|\s)ZetaLisp([,/]|\s)
# (/|\s)Zig([,/]|\s)
# (/|\s)ZOPL([,/]|\s)
# (/|\s)ZPL([,/]|\s)
# (/|\s)Z\+\+([,/]|\s)
# (/|\s)A\.NET([,/]|\s)
# (/|\s)A\-0\ System([,/]|\s)
# (/|\s)A\+([,/]|\s)
# (/|\s)ABAP([,/]|\s)
# (/|\s)ABC([,/]|\s)
# (/|\s)ABC\ ALGOL([,/]|\s)
# (/|\s)ACC([,/]|\s)
# (/|\s)Accent([,/]|\s)
# (/|\s)Ace\ DASL([,/]|\s)
# (/|\s)Action!([,/]|\s)
# (/|\s)ActionScript([,/]|\s)
# (/|\s)Actor([,/]|\s)
# (/|\s)Ada([,/]|\s)
# (/|\s)Adenine([,/]|\s)
# (/|\s)AdvPL([,/]|\s)
# (/|\s)Agda([,/]|\s)
# (/|\s)Agilent\ VEE([,/]|\s)
# (/|\s)Agora([,/]|\s)
# (/|\s)AIMMS([,/]|\s)
# (/|\s)Aldor([,/]|\s)
# (/|\s)Alef([,/]|\s)
# (/|\s)ALF([,/]|\s)
# (/|\s)ALGOL\ 58([,/]|\s)
# (/|\s)ALGOL\ 60([,/]|\s)
# (/|\s)ALGOL\ 68([,/]|\s)
# (/|\s)ALGOL\ W([,/]|\s)
# (/|\s)Alice([,/]|\s)
# (/|\s)Alma\-0([,/]|\s)
# (/|\s)AmbientTalk([,/]|\s)
# (/|\s)Amiga\ E([,/]|\s)
# (/|\s)AMOS([,/]|\s)
# (/|\s)AMPL([,/]|\s)
# (/|\s)AngelScript([,/]|\s)
# (/|\s)Apache\ Pig\ latin([,/]|\s)
# (/|\s)Apex([,/]|\s)
# (/|\s)APL([,/]|\s)
# (/|\s)App\ Inventor\ for\ Android's\ visual\ block\ language([,/]|\s)
# (/|\s)AppleScript([,/]|\s)
# (/|\s)APT([,/]|\s)
# (/|\s)Arc([,/]|\s)
# (/|\s)ARexx([,/]|\s)
# (/|\s)Argus([,/]|\s)
# (/|\s)Assembly\ language([,/]|\s)
# (/|\s)AutoIt([,/]|\s)
# (/|\s)AutoLISP\ /\ Visual\ LISP([,/]|\s)
# (/|\s)Averest([,/]|\s)
# (/|\s)AWK([,/]|\s)
# (/|\s)Axum([,/]|\s)
# (/|\s)B([,/]|\s)
# (/|\s)Babbage([,/]|\s)
# (/|\s)Ballerina([,/]|\s)
# (/|\s)Bash([,/]|\s)
# (/|\s)BASIC([,/]|\s)
# (/|\s)Batch\ file([,/]|\s)
# (/|\s)bc([,/]|\s)
# (/|\s)BCPL([,/]|\s)
# (/|\s)BeanShell([,/]|\s)
# (/|\s)Bertrand([,/]|\s)
# (/|\s)BETA([,/]|\s)
# (/|\s)BLISS([,/]|\s)
# (/|\s)Blockly([,/]|\s)
# (/|\s)BlooP([,/]|\s)
# (/|\s)Boo([,/]|\s)
# (/|\s)Boomerang([,/]|\s)
# (/|\s)Bosque([,/]|\s)
# (/|\s)C\ –\ ISO/IEC\ 9899([,/]|\s)
# (/|\s)C\-\-([,/]|\s)
# (/|\s)C\+\+([,/]|\s)
# (/|\s)C\*([,/]|\s)
# (/|\s)C\#([,/]|\s)
# (/|\s)C/AL([,/]|\s)
# (/|\s)Caché\ ObjectScript([,/]|\s)
# (/|\s)C\ Shell([,/]|\s)
# (/|\s)Caml([,/]|\s)
# (/|\s)Cayenne([,/]|\s)
# (/|\s)CDuce([,/]|\s)
# (/|\s)Cecil([,/]|\s)
# (/|\s)Cesil([,/]|\s)
# (/|\s)Céu([,/]|\s)
# (/|\s)Ceylon([,/]|\s)
# (/|\s)CFEngine([,/]|\s)
# (/|\s)Cg([,/]|\s)
# (/|\s)Ch([,/]|\s)
# (/|\s)Chapel([,/]|\s)
# (/|\s)Charm([,/]|\s)
# (/|\s)CHILL([,/]|\s)
# (/|\s)CHIP\-8([,/]|\s)
# (/|\s)ChucK([,/]|\s)
# (/|\s)Cilk([,/]|\s)
# (/|\s)CL([,/]|\s)
# (/|\s)Claire([,/]|\s)
# (/|\s)Clarion([,/]|\s)
# (/|\s)Clean([,/]|\s)
# (/|\s)Clipper([,/]|\s)
# (/|\s)CLIPS([,/]|\s)
# (/|\s)CLIST([,/]|\s)
# (/|\s)Clojure([,/]|\s)
# (/|\s)CLU([,/]|\s)
# (/|\s)CMS\-2([,/]|\s)
# (/|\s)COBOL\ –\ ISO/IEC\ 1989([,/]|\s)
# (/|\s)CobolScript\ –\ COBOL\ Scripting\ language([,/]|\s)
# (/|\s)Cobra([,/]|\s)
# (/|\s)CoffeeScript([,/]|\s)
# (/|\s)ColdFusion([,/]|\s)
# (/|\s)COMAL([,/]|\s)
# (/|\s)Combined\ Programming\ Language([,/]|\s)
# (/|\s)COMIT([,/]|\s)
# (/|\s)Common\ Intermediate\ Language([,/]|\s)
# (/|\s)Common\ Lisp([,/]|\s)
# (/|\s)COMPASS([,/]|\s)
# (/|\s)Component\ Pascal([,/]|\s)
# (/|\s)Constraint\ Handling\ Rules([,/]|\s)
# (/|\s)COMTRAN([,/]|\s)
# (/|\s)Cool([,/]|\s)
# (/|\s)Coq([,/]|\s)
# (/|\s)Coral\ 66([,/]|\s)
# (/|\s)CorVision([,/]|\s)
# (/|\s)COWSEL([,/]|\s)
# (/|\s)CPL([,/]|\s)
# (/|\s)Cryptol([,/]|\s)
# (/|\s)Crystal([,/]|\s)
# (/|\s)Csound([,/]|\s)
# (/|\s)Cuneiform([,/]|\s)
# (/|\s)Curl([,/]|\s)
# (/|\s)Curry([,/]|\s)
# (/|\s)Cybil([,/]|\s)
# (/|\s)Cyclone([,/]|\s)
# (/|\s)Cypher\ Query\ Language([,/]|\s)
# (/|\s)Cython([,/]|\s)
# (/|\s)CEEMAC([,/]|\s)
# (/|\s)D([,/]|\s)
# (/|\s)Dart([,/]|\s)
# (/|\s)Darwin([,/]|\s)
# (/|\s)DataFlex([,/]|\s)
# (/|\s)Datalog([,/]|\s)
# (/|\s)DATATRIEVE([,/]|\s)
# (/|\s)dBase([,/]|\s)
# (/|\s)dc([,/]|\s)
# (/|\s)DCL([,/]|\s)
# (/|\s)Delphi([,/]|\s)
# (/|\s)DinkC([,/]|\s)
# (/|\s)DIBOL([,/]|\s)
# (/|\s)Dog([,/]|\s)
# (/|\s)Draco([,/]|\s)
# (/|\s)DRAKON([,/]|\s)
# (/|\s)Dylan([,/]|\s)
# (/|\s)DYNAMO([,/]|\s)
# (/|\s)DAX([,/]|\s)
# (/|\s)E([,/]|\s)
# (/|\s)Ease([,/]|\s)
# (/|\s)Easy\ PL/I([,/]|\s)
# (/|\s)EASYTRIEVE\ PLUS([,/]|\s)
# (/|\s)eC([,/]|\s)
# (/|\s)ECMAScript([,/]|\s)
# (/|\s)Edinburgh\ IMP([,/]|\s)
# (/|\s)EGL([,/]|\s)
# (/|\s)Eiffel([,/]|\s)
# (/|\s)ELAN([,/]|\s)
# (/|\s)Elixir([,/]|\s)
# (/|\s)Elm([,/]|\s)
# (/|\s)Emacs\ Lisp([,/]|\s)
# (/|\s)Emerald([,/]|\s)
# (/|\s)Epigram([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)Erlang([,/]|\s)
# (/|\s)es([,/]|\s)
# (/|\s)Escher([,/]|\s)
# (/|\s)ESPOL([,/]|\s)
# (/|\s)Esterel([,/]|\s)
# (/|\s)Etoys([,/]|\s)
# (/|\s)Euclid([,/]|\s)
# (/|\s)Euler([,/]|\s)
# (/|\s)Euphoria([,/]|\s)
# (/|\s)EusLisp\ Robot\ Programming\ Language([,/]|\s)
# (/|\s)CMS\ EXEC([,/]|\s)
# (/|\s)EXEC\ 2([,/]|\s)
# (/|\s)Executable\ UML([,/]|\s)
# (/|\s)Ezhil([,/]|\s)
# (/|\s)F([,/]|\s)
# (/|\s)F\#([,/]|\s)
# (/|\s)F\*([,/]|\s)
# (/|\s)Factor([,/]|\s)
# (/|\s)Fantom([,/]|\s)
# (/|\s)FAUST([,/]|\s)
# (/|\s)FFP([,/]|\s)
# (/|\s)fish([,/]|\s)
# (/|\s)Fjölnir([,/]|\s)
# (/|\s)FL([,/]|\s)
# (/|\s)Flavors([,/]|\s)
# (/|\s)Flex([,/]|\s)
# (/|\s)Flix([,/]|\s)
# (/|\s)FlooP([,/]|\s)
# (/|\s)FLOW\-MASTIC([,/]|\s)
# (/|\s)FOCAL([,/]|\s)
# (/|\s)FOCUS([,/]|\s)
# (/|\s)FOIL([,/]|\s)
# (/|\s)FORMAC([,/]|\s)
# (/|\s)@Formula([,/]|\s)
# (/|\s)Forth([,/]|\s)
# (/|\s)Fortran\ –\ ISO/IEC\ 1539([,/]|\s)
# (/|\s)Fortress([,/]|\s)
# (/|\s)FP([,/]|\s)
# (/|\s)Franz\ Lisp([,/]|\s)
# (/|\s)Futhark([,/]|\s)
# (/|\s)F\-Script([,/]|\s)
# (/|\s)Game\ Maker\ Language([,/]|\s)
# (/|\s)GameMonkey\ Script([,/]|\s)
# (/|\s)GAMS([,/]|\s)
# (/|\s)GAP([,/]|\s)
# (/|\s)G\-code([,/]|\s)
# (/|\s)GDScript([,/]|\s)
# (/|\s)Genie([,/]|\s)
# (/|\s)GDL([,/]|\s)
# (/|\s)GEORGE([,/]|\s)
# (/|\s)GLSL([,/]|\s)
# (/|\s)GNU\ E([,/]|\s)
# (/|\s)GNU\ Guile([,/]|\s)
# (/|\s)Go([,/]|\s)
# (/|\s)Go!([,/]|\s)
# (/|\s)GOAL([,/]|\s)
# (/|\s)Gödel([,/]|\s)
# (/|\s)Golo([,/]|\s)
# (/|\s)GOM([,/]|\s)
# (/|\s)Google\ Apps\ Script([,/]|\s)
# (/|\s)Gosu([,/]|\s)
# (/|\s)GOTRAN([,/]|\s)
# (/|\s)GPSS([,/]|\s)
# (/|\s)GraphTalk([,/]|\s)
# (/|\s)GRASS([,/]|\s)
# (/|\s)Grasshopper([,/]|\s)
# (/|\s)Groovy([,/]|\s)
# (/|\s)Hack([,/]|\s)
# (/|\s)HAGGIS([,/]|\s)
# (/|\s)HAL/S([,/]|\s)
# (/|\s)Halide([,/]|\s)
# (/|\s)Hamilton\ C\ shell([,/]|\s)
# (/|\s)Harbour([,/]|\s)
# (/|\s)Hartmann\ pipelines([,/]|\s)
# (/|\s)Haskell([,/]|\s)
# (/|\s)Haxe([,/]|\s)
# (/|\s)Hermes([,/]|\s)
# (/|\s)High\ Level\ Assembly([,/]|\s)
# (/|\s)HLSL([,/]|\s)
# (/|\s)Hollywood([,/]|\s)
# (/|\s)HolyC([,/]|\s)
# (/|\s)Hop([,/]|\s)
# (/|\s)Hopscotch([,/]|\s)
# (/|\s)Hope([,/]|\s)
# (/|\s)Hugo([,/]|\s)
# (/|\s)Hume([,/]|\s)
# (/|\s)HyperTalk([,/]|\s)
# (/|\s)Io([,/]|\s)
# (/|\s)Icon([,/]|\s)
# (/|\s)IBM\ Basic\ assembly\ language([,/]|\s)
# (/|\s)IBM\ HAScript([,/]|\s)
# (/|\s)IBM\ Informix\-4GL([,/]|\s)
# (/|\s)IBM\ RPG([,/]|\s)
# (/|\s)IDL([,/]|\s)
# (/|\s)Idris([,/]|\s)
# (/|\s)Inform([,/]|\s)
# (/|\s)J([,/]|\s)
# (/|\s)J\#([,/]|\s)
# (/|\s)J\+\+([,/]|\s)
# (/|\s)JADE([,/]|\s)
# (/|\s)Jai([,/]|\s)
# (/|\s)JAL([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)JASS([,/]|\s)
# (/|\s)Java([,/]|\s)
# (/|\s)JavaFX\ Script([,/]|\s)
# (/|\s)JavaScript([,/]|\s)
# (/|\s)Jess([,/]|\s)
# (/|\s)JCL([,/]|\s)
# (/|\s)JEAN([,/]|\s)
# (/|\s)Join\ Java([,/]|\s)
# (/|\s)JOSS([,/]|\s)
# (/|\s)Joule([,/]|\s)
# (/|\s)JOVIAL([,/]|\s)
# (/|\s)Joy([,/]|\s)
# (/|\s)JScript([,/]|\s)
# (/|\s)JScript\ \.NET([,/]|\s)
# (/|\s)Julia([,/]|\s)
# (/|\s)Jython([,/]|\s)
# (/|\s)K([,/]|\s)
# (/|\s)Kaleidoscope([,/]|\s)
# (/|\s)Karel([,/]|\s)
# (/|\s)KEE([,/]|\s)
# (/|\s)Kixtart([,/]|\s)
# (/|\s)Klerer\-May\ System([,/]|\s)
# (/|\s)KIF([,/]|\s)
# (/|\s)Kojo([,/]|\s)
# (/|\s)Kotlin([,/]|\s)
# (/|\s)KRC([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRYPTON([,/]|\s)
# (/|\s)KornShell([,/]|\s)
# (/|\s)Kodu([,/]|\s)
# (/|\s)Kv([,/]|\s)
# (/|\s)LabVIEW([,/]|\s)
# (/|\s)Ladder([,/]|\s)
# (/|\s)LANSA([,/]|\s)
# (/|\s)Lasso([,/]|\s)
# (/|\s)Lava([,/]|\s)
# (/|\s)LC\-3([,/]|\s)
# (/|\s)Lean([,/]|\s)
# (/|\s)Legoscript([,/]|\s)
# (/|\s)LIL([,/]|\s)
# (/|\s)LilyPond([,/]|\s)
# (/|\s)Limbo([,/]|\s)
# (/|\s)Limnor([,/]|\s)
# (/|\s)LINC([,/]|\s)
# (/|\s)Lingo([,/]|\s)
# (/|\s)LINQ([,/]|\s)
# (/|\s)LIS([,/]|\s)
# (/|\s)LISA([,/]|\s)
# (/|\s)Language\ H([,/]|\s)
# (/|\s)Lisp\ –\ ISO/IEC\ 13816([,/]|\s)
# (/|\s)Lite\-C([,/]|\s)
# (/|\s)Lithe([,/]|\s)
# (/|\s)Little\ b([,/]|\s)
# (/|\s)LLL([,/]|\s)
# (/|\s)Logo([,/]|\s)
# (/|\s)Logtalk([,/]|\s)
# (/|\s)LotusScript([,/]|\s)
# (/|\s)LPC([,/]|\s)
# (/|\s)LSE([,/]|\s)
# (/|\s)LSL([,/]|\s)
# (/|\s)LiveCode([,/]|\s)
# (/|\s)LiveScript([,/]|\s)
# (/|\s)Lua([,/]|\s)
# (/|\s)Lucid([,/]|\s)
# (/|\s)Lustre([,/]|\s)
# (/|\s)LYaPAS([,/]|\s)
# (/|\s)Lynx([,/]|\s)
# (/|\s)M2001([,/]|\s)
# (/|\s)M4([,/]|\s)
# (/|\s)M\#([,/]|\s)
# (/|\s)Machine\ code([,/]|\s)
# (/|\s)MAD([,/]|\s)
# (/|\s)MAD/I([,/]|\s)
# (/|\s)Magik([,/]|\s)
# (/|\s)Magma([,/]|\s)
# (/|\s)Máni([,/]|\s)
# (/|\s)Maple([,/]|\s)
# (/|\s)MAPPER([,/]|\s)
# (/|\s)MARK\-IV([,/]|\s)
# (/|\s)Mary([,/]|\s)
# (/|\s)MATLAB([,/]|\s)
# (/|\s)MASM\ Microsoft\ Assembly\ x86([,/]|\s)
# (/|\s)MATH\-MATIC([,/]|\s)
# (/|\s)Maude\ system([,/]|\s)
# (/|\s)Maxima([,/]|\s)
# (/|\s)Max([,/]|\s)
# (/|\s)MaxScript\ internal\ language\ 3D\ Studio\ Max([,/]|\s)
# (/|\s)Maya([,/]|\s)
# (/|\s)MDL([,/]|\s)
# (/|\s)Mercury([,/]|\s)
# (/|\s)Mesa([,/]|\s)
# (/|\s)MHEG\-5([,/]|\s)
# (/|\s)Microcode([,/]|\s)
# (/|\s)MicroScript([,/]|\s)
# (/|\s)Microsoft\ Power\ Fx([,/]|\s)
# (/|\s)MIIS([,/]|\s)
# (/|\s)Milk([,/]|\s)
# (/|\s)MIMIC([,/]|\s)
# (/|\s)Mirah([,/]|\s)
# (/|\s)Miranda([,/]|\s)
# (/|\s)MIVA\ Script([,/]|\s)
# (/|\s)ML([,/]|\s)
# (/|\s)Model\ 204([,/]|\s)
# (/|\s)Modelica([,/]|\s)
# (/|\s)Modula([,/]|\s)
# (/|\s)Modula\-2([,/]|\s)
# (/|\s)Modula\-3([,/]|\s)
# (/|\s)Mohol([,/]|\s)
# (/|\s)MOO([,/]|\s)
# (/|\s)Mortran([,/]|\s)
# (/|\s)Mouse([,/]|\s)
# (/|\s)MPD([,/]|\s)
# (/|\s)MSL([,/]|\s)
# (/|\s)MUMPS([,/]|\s)
# (/|\s)MuPAD([,/]|\s)
# (/|\s)Mutan([,/]|\s)
# (/|\s)Mystic\ Programming\ Language([,/]|\s)
# (/|\s)NASM([,/]|\s)
# (/|\s)Napier88([,/]|\s)
# (/|\s)Neko([,/]|\s)
# (/|\s)Nemerle([,/]|\s)
# (/|\s)NESL([,/]|\s)
# (/|\s)Net\.Data([,/]|\s)
# (/|\s)NetLogo([,/]|\s)
# (/|\s)NetRexx([,/]|\s)
# (/|\s)NewLISP([,/]|\s)
# (/|\s)NEWP([,/]|\s)
# (/|\s)Newspeak([,/]|\s)
# (/|\s)NewtonScript([,/]|\s)
# (/|\s)Nial([,/]|\s)
# (/|\s)Nickle([,/]|\s)
# (/|\s)Nim([,/]|\s)
# (/|\s)Nix([,/]|\s)
# (/|\s)NPL([,/]|\s)
# (/|\s)Not\ eXactly\ C([,/]|\s)
# (/|\s)Not\ Quite\ C([,/]|\s)
# (/|\s)NSIS([,/]|\s)
# (/|\s)Nu([,/]|\s)
# (/|\s)NWScript([,/]|\s)
# (/|\s)NXT\-G([,/]|\s)
# (/|\s)o:XML([,/]|\s)
# (/|\s)Oak([,/]|\s)
# (/|\s)Oberon([,/]|\s)
# (/|\s)OBJ2([,/]|\s)
# (/|\s)Object\ Lisp([,/]|\s)
# (/|\s)ObjectLOGO([,/]|\s)
# (/|\s)Object\ REXX([,/]|\s)
# (/|\s)Object\ Pascal([,/]|\s)
# (/|\s)Objective\-C([,/]|\s)
# (/|\s)Objective\-J([,/]|\s)
# (/|\s)Obliq([,/]|\s)
# (/|\s)OCaml([,/]|\s)
# (/|\s)occam([,/]|\s)
# (/|\s)occam\-π([,/]|\s)
# (/|\s)Octave([,/]|\s)
# (/|\s)OmniMark([,/]|\s)
# (/|\s)Opa([,/]|\s)
# (/|\s)Opal([,/]|\s)
# (/|\s)OpenCL([,/]|\s)
# (/|\s)OpenEdge\ ABL([,/]|\s)
# (/|\s)OPL([,/]|\s)
# (/|\s)OpenVera([,/]|\s)
# (/|\s)OPS5([,/]|\s)
# (/|\s)OptimJ([,/]|\s)
# (/|\s)Orc([,/]|\s)
# (/|\s)ORCA/Modula\-2([,/]|\s)
# (/|\s)Oriel([,/]|\s)
# (/|\s)Orwell([,/]|\s)
# (/|\s)Oxygene([,/]|\s)
# (/|\s)Oz([,/]|\s)
# (/|\s)P([,/]|\s)
# (/|\s)P4([,/]|\s)
# (/|\s)P′′([,/]|\s)
# (/|\s)ParaSail([,/]|\s)
# (/|\s)PARI/GP([,/]|\s)
# (/|\s)Pascal\ –\ ISO\ 7185([,/]|\s)
# (/|\s)Pascal\ Script([,/]|\s)
# (/|\s)PCASTL([,/]|\s)
# (/|\s)PCF([,/]|\s)
# (/|\s)PEARL([,/]|\s)
# (/|\s)PeopleCode([,/]|\s)
# (/|\s)Perl([,/]|\s)
# (/|\s)PDL([,/]|\s)
# (/|\s)Pharo([,/]|\s)
# (/|\s)PHP([,/]|\s)
# (/|\s)Pico([,/]|\s)
# (/|\s)Picolisp([,/]|\s)
# (/|\s)Pict([,/]|\s)
# (/|\s)Pike([,/]|\s)
# (/|\s)PILOT([,/]|\s)
# (/|\s)Pipelines([,/]|\s)
# (/|\s)Pizza([,/]|\s)
# (/|\s)PL\-11([,/]|\s)
# (/|\s)PL/0([,/]|\s)
# (/|\s)PL/B([,/]|\s)
# (/|\s)PL/C([,/]|\s)
# (/|\s)PL/I\ –\ ISO\ 6160([,/]|\s)
# (/|\s)PL/M([,/]|\s)
# (/|\s)PL/P([,/]|\s)
# (/|\s)PL/SQL([,/]|\s)
# (/|\s)PL360([,/]|\s)
# (/|\s)PLANC([,/]|\s)
# (/|\s)Plankalkül([,/]|\s)
# (/|\s)Planner([,/]|\s)
# (/|\s)PLEX([,/]|\s)
# (/|\s)PLEXIL([,/]|\s)
# (/|\s)Plus([,/]|\s)
# (/|\s)POP\-11([,/]|\s)
# (/|\s)POP\-2([,/]|\s)
# (/|\s)PostScript([,/]|\s)
# (/|\s)PortablE([,/]|\s)
# (/|\s)POV\-Ray\ SDL([,/]|\s)
# (/|\s)Powerhouse([,/]|\s)
# (/|\s)PowerBuilder\ –\ 4GL\ GUI\ application\ generator\ from\ Sybase([,/]|\s)
# (/|\s)PowerShell([,/]|\s)
# (/|\s)PPL([,/]|\s)
# (/|\s)Processing([,/]|\s)
# (/|\s)Processing\.js([,/]|\s)
# (/|\s)Prograph([,/]|\s)
# (/|\s)PROIV([,/]|\s)
# (/|\s)Project\ Verona([,/]|\s)
# (/|\s)Prolog([,/]|\s)
# (/|\s)PROMAL([,/]|\s)
# (/|\s)Promela([,/]|\s)
# (/|\s)PROSE\ modeling\ language([,/]|\s)
# (/|\s)PROTEL([,/]|\s)
# (/|\s)ProvideX([,/]|\s)
# (/|\s)Pro\*C([,/]|\s)
# (/|\s)Pure([,/]|\s)
# (/|\s)Pure\ Data([,/]|\s)
# (/|\s)PureScript([,/]|\s)
# (/|\s)Python([,/]|\s)
# (/|\s)Q([,/]|\s)
# (/|\s)Q\#([,/]|\s)
# (/|\s)Qalb([,/]|\s)
# (/|\s)Quantum\ Computation\ Language([,/]|\s)
# (/|\s)QtScript([,/]|\s)
# (/|\s)QuakeC([,/]|\s)
# (/|\s)QPL([,/]|\s)
# (/|\s)\.QL([,/]|\s)
# (/|\s)R([,/]|\s)
# (/|\s)R\+\+([,/]|\s)
# (/|\s)Racket([,/]|\s)
# (/|\s)Raku([,/]|\s)
# (/|\s)RAPID([,/]|\s)
# (/|\s)Rapira([,/]|\s)
# (/|\s)Ratfiv([,/]|\s)
# (/|\s)Ratfor([,/]|\s)
# (/|\s)rc([,/]|\s)
# (/|\s)Reason([,/]|\s)
# (/|\s)REBOL([,/]|\s)
# (/|\s)Red([,/]|\s)
# (/|\s)Redcode([,/]|\s)
# (/|\s)REFAL([,/]|\s)
# (/|\s)REXX([,/]|\s)
# (/|\s)Rlab([,/]|\s)
# (/|\s)ROOP([,/]|\s)
# (/|\s)RPG([,/]|\s)
# (/|\s)RPL([,/]|\s)
# (/|\s)RSL([,/]|\s)
# (/|\s)RTL/2([,/]|\s)
# (/|\s)Ruby([,/]|\s)
# (/|\s)Rust([,/]|\s)
# (/|\s)S([,/]|\s)
# (/|\s)S2([,/]|\s)
# (/|\s)S3([,/]|\s)
# (/|\s)S\-Lang([,/]|\s)
# (/|\s)S\-PLUS([,/]|\s)
# (/|\s)SA\-C([,/]|\s)
# (/|\s)SabreTalk([,/]|\s)
# (/|\s)SAIL([,/]|\s)
# (/|\s)SAS([,/]|\s)
# (/|\s)SASL([,/]|\s)
# (/|\s)Sather([,/]|\s)
# (/|\s)Sawzall([,/]|\s)
# (/|\s)Scala([,/]|\s)
# (/|\s)Scheme([,/]|\s)
# (/|\s)Scilab([,/]|\s)
# (/|\s)Scratch([,/]|\s)
# (/|\s)Script\.NET([,/]|\s)
# (/|\s)Sed([,/]|\s)
# (/|\s)Seed7([,/]|\s)
# (/|\s)Self([,/]|\s)
# (/|\s)SenseTalk([,/]|\s)
# (/|\s)SequenceL([,/]|\s)
# (/|\s)Serpent([,/]|\s)
# (/|\s)SETL([,/]|\s)
# (/|\s)SIMPOL([,/]|\s)
# (/|\s)SIGNAL([,/]|\s)
# (/|\s)SiMPLE([,/]|\s)
# (/|\s)SIMSCRIPT([,/]|\s)
# (/|\s)Simula([,/]|\s)
# (/|\s)Simulink([,/]|\s)
# (/|\s)Singularity([,/]|\s)
# (/|\s)SISAL([,/]|\s)
# (/|\s)SLIP([,/]|\s)
# (/|\s)SMALL([,/]|\s)
# (/|\s)Smalltalk([,/]|\s)
# (/|\s)SML([,/]|\s)
# (/|\s)Strongtalk([,/]|\s)
# (/|\s)Snap!([,/]|\s)
# (/|\s)SNOBOL([,/]|\s)
# (/|\s)Snowball([,/]|\s)
# (/|\s)SOL([,/]|\s)
# (/|\s)Solidity([,/]|\s)
# (/|\s)SOPHAEROS([,/]|\s)
# (/|\s)Source([,/]|\s)
# (/|\s)SPARK([,/]|\s)
# (/|\s)Speakeasy([,/]|\s)
# (/|\s)Speedcode([,/]|\s)
# (/|\s)SPIN([,/]|\s)
# (/|\s)SP/k([,/]|\s)
# (/|\s)SPS([,/]|\s)
# (/|\s)SQL([,/]|\s)
# (/|\s)SQR([,/]|\s)
# (/|\s)Squeak([,/]|\s)
# (/|\s)Squirrel([,/]|\s)
# (/|\s)SR([,/]|\s)
# (/|\s)S/SL([,/]|\s)
# (/|\s)Starlogo([,/]|\s)
# (/|\s)Strand([,/]|\s)
# (/|\s)Stata([,/]|\s)
# (/|\s)Stateflow([,/]|\s)
# (/|\s)Subtext([,/]|\s)
# (/|\s)SBL([,/]|\s)
# (/|\s)SuperCollider([,/]|\s)
# (/|\s)SuperTalk([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)SYMPL([,/]|\s)
# (/|\s)SystemVerilog([,/]|\s)
# (/|\s)T([,/]|\s)
# (/|\s)TACL([,/]|\s)
# (/|\s)TACPOL([,/]|\s)
# (/|\s)TADS([,/]|\s)
# (/|\s)TAL([,/]|\s)
# (/|\s)Tcl([,/]|\s)
# (/|\s)Tea([,/]|\s)
# (/|\s)TECO([,/]|\s)
# (/|\s)TELCOMP([,/]|\s)
# (/|\s)TeX([,/]|\s)
# (/|\s)TEX([,/]|\s)
# (/|\s)TIE([,/]|\s)
# (/|\s)TMG([,/]|\s)
# (/|\s)Tom([,/]|\s)
# (/|\s)Toi([,/]|\s)
# (/|\s)Topspeed([,/]|\s)
# (/|\s)TPU([,/]|\s)
# (/|\s)Trac([,/]|\s)
# (/|\s)TTM([,/]|\s)
# (/|\s)T\-SQL([,/]|\s)
# (/|\s)Transcript([,/]|\s)
# (/|\s)TTCN([,/]|\s)
# (/|\s)Turing([,/]|\s)
# (/|\s)TUTOR([,/]|\s)
# (/|\s)TXL([,/]|\s)
# (/|\s)TypeScript([,/]|\s)
# (/|\s)Tynker([,/]|\s)
# (/|\s)Ubercode([,/]|\s)
# (/|\s)UCSD\ Pascal([,/]|\s)
# (/|\s)Umple([,/]|\s)
# (/|\s)Unicon([,/]|\s)
# (/|\s)Uniface([,/]|\s)
# (/|\s)UNITY([,/]|\s)
# (/|\s)Unix\ shell([,/]|\s)
# (/|\s)UnrealScript([,/]|\s)
# (/|\s)Vala([,/]|\s)
# (/|\s)Verilog([,/]|\s)
# (/|\s)VHDL([,/]|\s)
# (/|\s)Vim\ script([,/]|\s)
# (/|\s)Viper([,/]|\s)
# (/|\s)Visual\ DataFlex([,/]|\s)
# (/|\s)Visual\ DialogScript([,/]|\s)
# (/|\s)Visual\ FoxPro([,/]|\s)
# (/|\s)Visual\ J\+\+([,/]|\s)
# (/|\s)Visual\ LISP([,/]|\s)
# (/|\s)Visual\ Objects([,/]|\s)
# (/|\s)Visual\ Prolog([,/]|\s)
# (/|\s)WATFIV,\ WATFOR([,/]|\s)
# (/|\s)WebAssembly([,/]|\s)
# (/|\s)WebDNA([,/]|\s)
# (/|\s)Whiley([,/]|\s)
# (/|\s)Winbatch([,/]|\s)
# (/|\s)Wolfram\ Language([,/]|\s)
# (/|\s)Wyvern([,/]|\s)
# (/|\s)X\+\+([,/]|\s)
# (/|\s)X10([,/]|\s)
# (/|\s)xBase([,/]|\s)
# (/|\s)xBase\+\+([,/]|\s)
# (/|\s)XBL([,/]|\s)
# (/|\s)XC([,/]|\s)
# (/|\s)xHarbour([,/]|\s)
# (/|\s)XL([,/]|\s)
# (/|\s)Xojo([,/]|\s)
# (/|\s)XOTcl([,/]|\s)
# (/|\s)Xod([,/]|\s)
# (/|\s)XPL([,/]|\s)
# (/|\s)XPL0([,/]|\s)
# (/|\s)XQuery([,/]|\s)
# (/|\s)XSB([,/]|\s)
# (/|\s)XSharp([,/]|\s)
# (/|\s)XSLT([,/]|\s)
# (/|\s)Xtend([,/]|\s)
# (/|\s)Yorick([,/]|\s)
# (/|\s)YQL([,/]|\s)
# (/|\s)Yoix([,/]|\s)
# (/|\s)YUI([,/]|\s)
# (/|\s)Z\ notation([,/]|\s)
# (/|\s)Zebra,\ ZPL,\ ZPL2([,/]|\s)
# (/|\s)Zeno([,/]|\s)
# (/|\s)ZetaLisp([,/]|\s)
# (/|\s)Zig([,/]|\s)
# (/|\s)ZOPL([,/]|\s)
# (/|\s)ZPL([,/]|\s)
# (/|\s)Z\+\+([,/]|\s)
# (/|\s)A\.NET([,/]|\s)
# (/|\s)A\-0\ System([,/]|\s)
# (/|\s)A\+([,/]|\s)
# (/|\s)ABAP([,/]|\s)
# (/|\s)ABC([,/]|\s)
# (/|\s)ABC\ ALGOL([,/]|\s)
# (/|\s)ACC([,/]|\s)
# (/|\s)Accent([,/]|\s)
# (/|\s)Ace\ DASL([,/]|\s)
# (/|\s)Action!([,/]|\s)
# (/|\s)ActionScript([,/]|\s)
# (/|\s)Actor([,/]|\s)
# (/|\s)Ada([,/]|\s)
# (/|\s)Adenine([,/]|\s)
# (/|\s)AdvPL([,/]|\s)
# (/|\s)Agda([,/]|\s)
# (/|\s)Agilent\ VEE([,/]|\s)
# (/|\s)Agora([,/]|\s)
# (/|\s)AIMMS([,/]|\s)
# (/|\s)Aldor([,/]|\s)
# ...
# (/|\s)Caml([,/]|\s)
# (/|\s)Cayenne([,/]|\s)
# (/|\s)CDuce([,/]|\s)
# (/|\s)Cecil([,/]|\s)
# (/|\s)Cesil([,/]|\s)
# (/|\s)Céu([,/]|\s)
# (/|\s)Ceylon([,/]|\s)
# (/|\s)CFEngine([,/]|\s)
# (/|\s)Cg([,/]|\s)
# (/|\s)Ch([,/]|\s)
# (/|\s)Chapel([,/]|\s)
# (/|\s)Charm([,/]|\s)
# (/|\s)CHILL([,/]|\s)
# (/|\s)CHIP\-8([,/]|\s)
# (/|\s)ChucK([,/]|\s)
# (/|\s)Cilk([,/]|\s)
# (/|\s)CL([,/]|\s)
# (/|\s)Claire([,/]|\s)
# (/|\s)Clarion([,/]|\s)
# (/|\s)Clean([,/]|\s)
# (/|\s)Clipper([,/]|\s)
# (/|\s)CLIPS([,/]|\s)
# (/|\s)CLIST([,/]|\s)
# (/|\s)Clojure([,/]|\s)
# (/|\s)CLU([,/]|\s)
# (/|\s)CMS\-2([,/]|\s)
# (/|\s)COBOL\ –\ ISO/IEC\ 1989([,/]|\s)
# (/|\s)CobolScript\ –\ COBOL\ Scripting\ language([,/]|\s)
# (/|\s)Cobra([,/]|\s)
# (/|\s)CoffeeScript([,/]|\s)
# (/|\s)ColdFusion([,/]|\s)
# (/|\s)COMAL([,/]|\s)
# (/|\s)Combined\ Programming\ Language([,/]|\s)
# (/|\s)COMIT([,/]|\s)
# (/|\s)Common\ Intermediate\ Language([,/]|\s)
# (/|\s)Common\ Lisp([,/]|\s)
# (/|\s)COMPASS([,/]|\s)
# (/|\s)Component\ Pascal([,/]|\s)
# (/|\s)Constraint\ Handling\ Rules([,/]|\s)
# (/|\s)COMTRAN([,/]|\s)
# (/|\s)Cool([,/]|\s)
# (/|\s)Coq([,/]|\s)
# (/|\s)Coral\ 66([,/]|\s)
# (/|\s)CorVision([,/]|\s)
# (/|\s)COWSEL([,/]|\s)
# (/|\s)CPL([,/]|\s)
# (/|\s)Cryptol([,/]|\s)
# (/|\s)Crystal([,/]|\s)
# (/|\s)Csound([,/]|\s)
# (/|\s)Cuneiform([,/]|\s)
# (/|\s)Curl([,/]|\s)
# (/|\s)Curry([,/]|\s)
# (/|\s)Cybil([,/]|\s)
# (/|\s)Cyclone([,/]|\s)
# (/|\s)Cypher\ Query\ Language([,/]|\s)
# (/|\s)Cython([,/]|\s)
# (/|\s)CEEMAC([,/]|\s)
# (/|\s)D([,/]|\s)
# (/|\s)Dart([,/]|\s)
# (/|\s)Darwin([,/]|\s)
# (/|\s)DataFlex([,/]|\s)
# (/|\s)Datalog([,/]|\s)
# (/|\s)DATATRIEVE([,/]|\s)
# (/|\s)dBase([,/]|\s)
# (/|\s)dc([,/]|\s)
# (/|\s)DCL([,/]|\s)
# (/|\s)Delphi([,/]|\s)
# (/|\s)DinkC([,/]|\s)
# (/|\s)DIBOL([,/]|\s)
# (/|\s)Dog([,/]|\s)
# (/|\s)Draco([,/]|\s)
# (/|\s)DRAKON([,/]|\s)
# (/|\s)Dylan([,/]|\s)
# (/|\s)DYNAMO([,/]|\s)
# (/|\s)DAX([,/]|\s)
# (/|\s)E([,/]|\s)
# (/|\s)Ease([,/]|\s)
# (/|\s)Easy\ PL/I([,/]|\s)
# (/|\s)EASYTRIEVE\ PLUS([,/]|\s)
# (/|\s)eC([,/]|\s)
# (/|\s)ECMAScript([,/]|\s)
# (/|\s)Edinburgh\ IMP([,/]|\s)
# (/|\s)EGL([,/]|\s)
# (/|\s)Eiffel([,/]|\s)
# (/|\s)ELAN([,/]|\s)
# (/|\s)Elixir([,/]|\s)
# (/|\s)Elm([,/]|\s)
# (/|\s)Emacs\ Lisp([,/]|\s)
# (/|\s)Emerald([,/]|\s)
# (/|\s)Epigram([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)EPL([,/]|\s)
# (/|\s)Erlang([,/]|\s)
# (/|\s)es([,/]|\s)
# (/|\s)Escher([,/]|\s)
# (/|\s)ESPOL([,/]|\s)
# (/|\s)Esterel([,/]|\s)
# (/|\s)Etoys([,/]|\s)
# (/|\s)Euclid([,/]|\s)
# (/|\s)Euler([,/]|\s)
# (/|\s)Euphoria([,/]|\s)
# (/|\s)EusLisp\ Robot\ Programming\ Language([,/]|\s)
# (/|\s)CMS\ EXEC([,/]|\s)
# (/|\s)EXEC\ 2([,/]|\s)
# (/|\s)Executable\ UML([,/]|\s)
# (/|\s)Ezhil([,/]|\s)
# (/|\s)F([,/]|\s)
# (/|\s)F\#([,/]|\s)
# (/|\s)F\*([,/]|\s)
# (/|\s)Factor([,/]|\s)
# (/|\s)Fantom([,/]|\s)
# (/|\s)FAUST([,/]|\s)
# (/|\s)FFP([,/]|\s)
# (/|\s)fish([,/]|\s)
# (/|\s)Fjölnir([,/]|\s)
# (/|\s)FL([,/]|\s)
# (/|\s)Flavors([,/]|\s)
# (/|\s)Flex([,/]|\s)
# (/|\s)Flix([,/]|\s)
# (/|\s)FlooP([,/]|\s)
# (/|\s)FLOW\-MASTIC([,/]|\s)
# (/|\s)FOCAL([,/]|\s)
# (/|\s)FOCUS([,/]|\s)
# (/|\s)FOIL([,/]|\s)
# (/|\s)FORMAC([,/]|\s)
# (/|\s)@Formula([,/]|\s)
# (/|\s)Forth([,/]|\s)
# (/|\s)Fortran\ –\ ISO/IEC\ 1539([,/]|\s)
# (/|\s)Fortress([,/]|\s)
# (/|\s)FP([,/]|\s)
# (/|\s)Franz\ Lisp([,/]|\s)
# (/|\s)Futhark([,/]|\s)
# (/|\s)F\-Script([,/]|\s)
# (/|\s)Game\ Maker\ Language([,/]|\s)
# (/|\s)GameMonkey\ Script([,/]|\s)
# (/|\s)GAMS([,/]|\s)
# (/|\s)GAP([,/]|\s)
# (/|\s)G\-code([,/]|\s)
# (/|\s)GDScript([,/]|\s)
# (/|\s)Genie([,/]|\s)
# (/|\s)GDL([,/]|\s)
# (/|\s)GEORGE([,/]|\s)
# (/|\s)GLSL([,/]|\s)
# (/|\s)GNU\ E([,/]|\s)
# (/|\s)GNU\ Guile([,/]|\s)
# (/|\s)Go([,/]|\s)
# (/|\s)Go!([,/]|\s)
# (/|\s)GOAL([,/]|\s)
# (/|\s)Gödel([,/]|\s)
# (/|\s)Golo([,/]|\s)
# (/|\s)GOM([,/]|\s)
# (/|\s)Google\ Apps\ Script([,/]|\s)
# (/|\s)Gosu([,/]|\s)
# (/|\s)GOTRAN([,/]|\s)
# (/|\s)GPSS([,/]|\s)
# (/|\s)GraphTalk([,/]|\s)
# (/|\s)GRASS([,/]|\s)
# (/|\s)Grasshopper([,/]|\s)
# (/|\s)Groovy([,/]|\s)
# (/|\s)Hack([,/]|\s)
# (/|\s)HAGGIS([,/]|\s)
# (/|\s)HAL/S([,/]|\s)
# (/|\s)Halide([,/]|\s)
# (/|\s)Hamilton\ C\ shell([,/]|\s)
# (/|\s)Harbour([,/]|\s)
# (/|\s)Hartmann\ pipelines([,/]|\s)
# (/|\s)Haskell([,/]|\s)
# (/|\s)Haxe([,/]|\s)
# (/|\s)Hermes([,/]|\s)
# (/|\s)High\ Level\ Assembly([,/]|\s)
# (/|\s)HLSL([,/]|\s)
# (/|\s)Hollywood([,/]|\s)
# (/|\s)HolyC([,/]|\s)
# (/|\s)Hop([,/]|\s)
# (/|\s)Hopscotch([,/]|\s)
# (/|\s)Hope([,/]|\s)
# (/|\s)Hugo([,/]|\s)
# (/|\s)Hume([,/]|\s)
# (/|\s)HyperTalk([,/]|\s)
# (/|\s)Io([,/]|\s)
# (/|\s)Icon([,/]|\s)
# (/|\s)IBM\ Basic\ assembly\ language([,/]|\s)
# (/|\s)IBM\ HAScript([,/]|\s)
# (/|\s)IBM\ Informix\-4GL([,/]|\s)
# (/|\s)IBM\ RPG([,/]|\s)
# (/|\s)IDL([,/]|\s)
# (/|\s)Idris([,/]|\s)
# (/|\s)Inform([,/]|\s)
# (/|\s)J([,/]|\s)
# (/|\s)J\#([,/]|\s)
# (/|\s)J\+\+([,/]|\s)
# (/|\s)JADE([,/]|\s)
# (/|\s)Jai([,/]|\s)
# (/|\s)JAL([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)Janus([,/]|\s)
# (/|\s)JASS([,/]|\s)
# (/|\s)Java([,/]|\s)
# (/|\s)JavaFX\ Script([,/]|\s)
# (/|\s)JavaScript([,/]|\s)
# (/|\s)Jess([,/]|\s)
# (/|\s)JCL([,/]|\s)
# (/|\s)JEAN([,/]|\s)
# (/|\s)Join\ Java([,/]|\s)
# (/|\s)JOSS([,/]|\s)
# (/|\s)Joule([,/]|\s)
# (/|\s)JOVIAL([,/]|\s)
# (/|\s)Joy([,/]|\s)
# (/|\s)JScript([,/]|\s)
# (/|\s)JScript\ \.NET([,/]|\s)
# (/|\s)Julia([,/]|\s)
# (/|\s)Jython([,/]|\s)
# (/|\s)K([,/]|\s)
# (/|\s)Kaleidoscope([,/]|\s)
# (/|\s)Karel([,/]|\s)
# (/|\s)KEE([,/]|\s)
# (/|\s)Kixtart([,/]|\s)
# (/|\s)Klerer\-May\ System([,/]|\s)
# (/|\s)KIF([,/]|\s)
# (/|\s)Kojo([,/]|\s)
# (/|\s)Kotlin([,/]|\s)
# (/|\s)KRC([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRL([,/]|\s)
# (/|\s)KRYPTON([,/]|\s)
# (/|\s)KornShell([,/]|\s)
# (/|\s)Kodu([,/]|\s)
# (/|\s)Kv([,/]|\s)
# (/|\s)LabVIEW([,/]|\s)
# (/|\s)Ladder([,/]|\s)
# (/|\s)LANSA([,/]|\s)
# (/|\s)Lasso([,/]|\s)
# (/|\s)Lava([,/]|\s)
# (/|\s)LC\-3([,/]|\s)
# (/|\s)Lean([,/]|\s)
# (/|\s)Legoscript([,/]|\s)
# (/|\s)LIL([,/]|\s)
# (/|\s)LilyPond([,/]|\s)
# (/|\s)Limbo([,/]|\s)
# (/|\s)Limnor([,/]|\s)
# (/|\s)LINC([,/]|\s)
# (/|\s)Lingo([,/]|\s)
# (/|\s)LINQ([,/]|\s)
# (/|\s)LIS([,/]|\s)
# (/|\s)LISA([,/]|\s)
# (/|\s)Language\ H([,/]|\s)
# (/|\s)Lisp\ –\ ISO/IEC\ 13816([,/]|\s)
# (/|\s)Lite\-C([,/]|\s)
# (/|\s)Lithe([,/]|\s)
# (/|\s)Little\ b([,/]|\s)
# (/|\s)LLL([,/]|\s)
# (/|\s)Logo([,/]|\s)
# (/|\s)Logtalk([,/]|\s)
# (/|\s)LotusScript([,/]|\s)
# (/|\s)LPC([,/]|\s)
# (/|\s)LSE([,/]|\s)
# (/|\s)LSL([,/]|\s)
# (/|\s)LiveCode([,/]|\s)
# (/|\s)LiveScript([,/]|\s)
# (/|\s)Lua([,/]|\s)
# (/|\s)Lucid([,/]|\s)
# (/|\s)Lustre([,/]|\s)
# (/|\s)LYaPAS([,/]|\s)
# (/|\s)Lynx([,/]|\s)
# (/|\s)M2001([,/]|\s)
# (/|\s)M4([,/]|\s)
# (/|\s)M\#([,/]|\s)
# (/|\s)Machine\ code([,/]|\s)
# (/|\s)MAD([,/]|\s)
# (/|\s)MAD/I([,/]|\s)
# (/|\s)Magik([,/]|\s)
# (/|\s)Magma([,/]|\s)
# (/|\s)Máni([,/]|\s)
# (/|\s)Maple([,/]|\s)
# (/|\s)MAPPER([,/]|\s)
# (/|\s)MARK\-IV([,/]|\s)
# (/|\s)Mary([,/]|\s)
# (/|\s)MATLAB([,/]|\s)
# (/|\s)MASM\ Microsoft\ Assembly\ x86([,/]|\s)
# (/|\s)MATH\-MATIC([,/]|\s)
# (/|\s)Maude\ system([,/]|\s)
# (/|\s)Maxima([,/]|\s)
# (/|\s)Max([,/]|\s)
# (/|\s)MaxScript\ internal\ language\ 3D\ Studio\ Max([,/]|\s)
# (/|\s)Maya([,/]|\s)
# (/|\s)MDL([,/]|\s)
# (/|\s)Mercury([,/]|\s)
# (/|\s)Mesa([,/]|\s)
# (/|\s)MHEG\-5([,/]|\s)
# (/|\s)Microcode([,/]|\s)
# (/|\s)MicroScript([,/]|\s)
# (/|\s)Microsoft\ Power\ Fx([,/]|\s)
# (/|\s)MIIS([,/]|\s)
# (/|\s)Milk([,/]|\s)
# (/|\s)MIMIC([,/]|\s)
# (/|\s)Mirah([,/]|\s)
# (/|\s)Miranda([,/]|\s)
# (/|\s)MIVA\ Script([,/]|\s)
# (/|\s)ML([,/]|\s)
# (/|\s)Model\ 204([,/]|\s)
# (/|\s)Modelica([,/]|\s)
# (/|\s)Modula([,/]|\s)
# (/|\s)Modula\-2([,/]|\s)
# (/|\s)Modula\-3([,/]|\s)
# (/|\s)Mohol([,/]|\s)
# (/|\s)MOO([,/]|\s)
# (/|\s)Mortran([,/]|\s)
# (/|\s)Mouse([,/]|\s)
# (/|\s)MPD([,/]|\s)
# (/|\s)MSL([,/]|\s)
# (/|\s)MUMPS([,/]|\s)
# (/|\s)MuPAD([,/]|\s)
# (/|\s)Mutan([,/]|\s)
# (/|\s)Mystic\ Programming\ Language([,/]|\s)
# (/|\s)NASM([,/]|\s)
# (/|\s)Napier88([,/]|\s)
# (/|\s)Neko([,/]|\s)
# (/|\s)Nemerle([,/]|\s)
# (/|\s)NESL([,/]|\s)
# (/|\s)Net\.Data([,/]|\s)
# (/|\s)NetLogo([,/]|\s)
# (/|\s)NetRexx([,/]|\s)
# (/|\s)NewLISP([,/]|\s)
# (/|\s)NEWP([,/]|\s)
# (/|\s)Newspeak([,/]|\s)
# (/|\s)NewtonScript([,/]|\s)
# (/|\s)Nial([,/]|\s)
# (/|\s)Nickle([,/]|\s)
# (/|\s)Nim([,/]|\s)
# (/|\s)Nix([,/]|\s)
# (/|\s)NPL([,/]|\s)
# (/|\s)Not\ eXactly\ C([,/]|\s)
# (/|\s)Not\ Quite\ C([,/]|\s)
# (/|\s)NSIS([,/]|\s)
# (/|\s)Nu([,/]|\s)
# (/|\s)NWScript([,/]|\s)
# (/|\s)NXT\-G([,/]|\s)
# (/|\s)o:XML([,/]|\s)
# (/|\s)Oak([,/]|\s)
# (/|\s)Oberon([,/]|\s)
# (/|\s)OBJ2([,/]|\s)
# (/|\s)Object\ Lisp([,/]|\s)
# (/|\s)ObjectLOGO([,/]|\s)
# (/|\s)Object\ REXX([,/]|\s)
# (/|\s)Object\ Pascal([,/]|\s)
# (/|\s)Objective\-C([,/]|\s)
# (/|\s)Objective\-J([,/]|\s)
# (/|\s)Obliq([,/]|\s)
# (/|\s)OCaml([,/]|\s)
# (/|\s)occam([,/]|\s)
# (/|\s)occam\-π([,/]|\s)
# (/|\s)Octave([,/]|\s)
# (/|\s)OmniMark([,/]|\s)
# (/|\s)Opa([,/]|\s)
# (/|\s)Opal([,/]|\s)
# (/|\s)OpenCL([,/]|\s)
# (/|\s)OpenEdge\ ABL([,/]|\s)
# (/|\s)OPL([,/]|\s)
# (/|\s)OpenVera([,/]|\s)
# (/|\s)OPS5([,/]|\s)
# (/|\s)OptimJ([,/]|\s)
# (/|\s)Orc([,/]|\s)
# (/|\s)ORCA/Modula\-2([,/]|\s)
# (/|\s)Oriel([,/]|\s)
# (/|\s)Orwell([,/]|\s)
# (/|\s)Oxygene([,/]|\s)
# (/|\s)Oz([,/]|\s)
# (/|\s)P([,/]|\s)
# (/|\s)P4([,/]|\s)
# (/|\s)P′′([,/]|\s)
# (/|\s)ParaSail([,/]|\s)
# (/|\s)PARI/GP([,/]|\s)
# (/|\s)Pascal\ –\ ISO\ 7185([,/]|\s)
# (/|\s)Pascal\ Script([,/]|\s)
# (/|\s)PCASTL([,/]|\s)
# (/|\s)PCF([,/]|\s)
# (/|\s)PEARL([,/]|\s)
# (/|\s)PeopleCode([,/]|\s)
# (/|\s)Perl([,/]|\s)
# (/|\s)PDL([,/]|\s)
# (/|\s)Pharo([,/]|\s)
# (/|\s)PHP([,/]|\s)
# (/|\s)Pico([,/]|\s)
# (/|\s)Picolisp([,/]|\s)
# (/|\s)Pict([,/]|\s)
# (/|\s)Pike([,/]|\s)
# (/|\s)PILOT([,/]|\s)
# (/|\s)Pipelines([,/]|\s)
# (/|\s)Pizza([,/]|\s)
# (/|\s)PL\-11([,/]|\s)
# (/|\s)PL/0([,/]|\s)
# (/|\s)PL/B([,/]|\s)
# (/|\s)PL/C([,/]|\s)
# (/|\s)PL/I\ –\ ISO\ 6160([,/]|\s)
# (/|\s)PL/M([,/]|\s)
# (/|\s)PL/P([,/]|\s)
# (/|\s)PL/SQL([,/]|\s)
# (/|\s)PL360([,/]|\s)
# (/|\s)PLANC([,/]|\s)
# (/|\s)Plankalkül([,/]|\s)
# (/|\s)Planner([,/]|\s)
# (/|\s)PLEX([,/]|\s)
# (/|\s)PLEXIL([,/]|\s)
# (/|\s)Plus([,/]|\s)
# (/|\s)POP\-11([,/]|\s)
# (/|\s)POP\-2([,/]|\s)
# (/|\s)PostScript([,/]|\s)
# (/|\s)PortablE([,/]|\s)
# (/|\s)POV\-Ray\ SDL([,/]|\s)
# (/|\s)Powerhouse([,/]|\s)
# (/|\s)PowerBuilder\ –\ 4GL\ GUI\ application\ generator\ from\ Sybase([,/]|\s)
# (/|\s)PowerShell([,/]|\s)
# (/|\s)PPL([,/]|\s)
# (/|\s)Processing([,/]|\s)
# (/|\s)Processing\.js([,/]|\s)
# (/|\s)Prograph([,/]|\s)
# (/|\s)PROIV([,/]|\s)
# (/|\s)Project\ Verona([,/]|\s)
# (/|\s)Prolog([,/]|\s)
# (/|\s)PROMAL([,/]|\s)
# (/|\s)Promela([,/]|\s)
# (/|\s)PROSE\ modeling\ language([,/]|\s)
# (/|\s)PROTEL([,/]|\s)
# (/|\s)ProvideX([,/]|\s)
# (/|\s)Pro\*C([,/]|\s)
# (/|\s)Pure([,/]|\s)
# (/|\s)Pure\ Data([,/]|\s)
# (/|\s)PureScript([,/]|\s)
# (/|\s)Python([,/]|\s)
# (/|\s)Q([,/]|\s)
# (/|\s)Q\#([,/]|\s)
# (/|\s)Qalb([,/]|\s)
# (/|\s)Quantum\ Computation\ Language([,/]|\s)
# (/|\s)QtScript([,/]|\s)
# (/|\s)QuakeC([,/]|\s)
# (/|\s)QPL([,/]|\s)
# (/|\s)\.QL([,/]|\s)
# (/|\s)R([,/]|\s)
# (/|\s)R\+\+([,/]|\s)
# (/|\s)Racket([,/]|\s)
# (/|\s)Raku([,/]|\s)
# (/|\s)RAPID([,/]|\s)
# (/|\s)Rapira([,/]|\s)
# (/|\s)Ratfiv([,/]|\s)
# (/|\s)Ratfor([,/]|\s)
# (/|\s)rc([,/]|\s)
# (/|\s)Reason([,/]|\s)
# (/|\s)REBOL([,/]|\s)
# (/|\s)Red([,/]|\s)
# (/|\s)Redcode([,/]|\s)
# (/|\s)REFAL([,/]|\s)
# (/|\s)REXX([,/]|\s)
# (/|\s)Rlab([,/]|\s)
# (/|\s)ROOP([,/]|\s)
# (/|\s)RPG([,/]|\s)
# (/|\s)RPL([,/]|\s)
# (/|\s)RSL([,/]|\s)
# (/|\s)RTL/2([,/]|\s)
# (/|\s)Ruby([,/]|\s)
# (/|\s)Rust([,/]|\s)
# (/|\s)S([,/]|\s)
# (/|\s)S2([,/]|\s)
# (/|\s)S3([,/]|\s)
# (/|\s)S\-Lang([,/]|\s)
# (/|\s)S\-PLUS([,/]|\s)
# (/|\s)SA\-C([,/]|\s)
# (/|\s)SabreTalk([,/]|\s)
# (/|\s)SAIL([,/]|\s)
# (/|\s)SAS([,/]|\s)
# (/|\s)SASL([,/]|\s)
# (/|\s)Sather([,/]|\s)
# (/|\s)Sawzall([,/]|\s)
# (/|\s)Scala([,/]|\s)
# (/|\s)Scheme([,/]|\s)
# (/|\s)Scilab([,/]|\s)
# (/|\s)Scratch([,/]|\s)
# (/|\s)Script\.NET([,/]|\s)
# (/|\s)Sed([,/]|\s)
# (/|\s)Seed7([,/]|\s)
# (/|\s)Self([,/]|\s)
# (/|\s)SenseTalk([,/]|\s)
# (/|\s)SequenceL([,/]|\s)
# (/|\s)Serpent([,/]|\s)
# (/|\s)SETL([,/]|\s)
# (/|\s)SIMPOL([,/]|\s)
# (/|\s)SIGNAL([,/]|\s)
# (/|\s)SiMPLE([,/]|\s)
# (/|\s)SIMSCRIPT([,/]|\s)
# (/|\s)Simula([,/]|\s)
# (/|\s)Simulink([,/]|\s)
# (/|\s)Singularity([,/]|\s)
# (/|\s)SISAL([,/]|\s)
# (/|\s)SLIP([,/]|\s)
# (/|\s)SMALL([,/]|\s)
# (/|\s)Smalltalk([,/]|\s)
# (/|\s)SML([,/]|\s)
# (/|\s)Strongtalk([,/]|\s)
# (/|\s)Snap!([,/]|\s)
# (/|\s)SNOBOL([,/]|\s)
# (/|\s)Snowball([,/]|\s)
# (/|\s)SOL([,/]|\s)
# (/|\s)Solidity([,/]|\s)
# (/|\s)SOPHAEROS([,/]|\s)
# (/|\s)Source([,/]|\s)
# (/|\s)SPARK([,/]|\s)
# (/|\s)Speakeasy([,/]|\s)
# (/|\s)Speedcode([,/]|\s)
# (/|\s)SPIN([,/]|\s)
# (/|\s)SP/k([,/]|\s)
# (/|\s)SPS([,/]|\s)
# (/|\s)SQL([,/]|\s)
# (/|\s)SQR([,/]|\s)
# (/|\s)Squeak([,/]|\s)
# (/|\s)Squirrel([,/]|\s)
# (/|\s)SR([,/]|\s)
# (/|\s)S/SL([,/]|\s)
# (/|\s)Starlogo([,/]|\s)
# (/|\s)Strand([,/]|\s)
# (/|\s)Stata([,/]|\s)
# (/|\s)Stateflow([,/]|\s)
# (/|\s)Subtext([,/]|\s)
# (/|\s)SBL([,/]|\s)
# (/|\s)SuperCollider([,/]|\s)
# (/|\s)SuperTalk([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)Swift([,/]|\s)
# (/|\s)SYMPL([,/]|\s)
# (/|\s)SystemVerilog([,/]|\s)
# (/|\s)T([,/]|\s)
# (/|\s)TACL([,/]|\s)
# (/|\s)TACPOL([,/]|\s)
# (/|\s)TADS([,/]|\s)
# (/|\s)TAL([,/]|\s)
# (/|\s)Tcl([,/]|\s)
# (/|\s)Tea([,/]|\s)
# (/|\s)TECO([,/]|\s)
# (/|\s)TELCOMP([,/]|\s)
# (/|\s)TeX([,/]|\s)
# (/|\s)TEX([,/]|\s)
# (/|\s)TIE([,/]|\s)
# (/|\s)TMG([,/]|\s)
# (/|\s)Tom([,/]|\s)
# (/|\s)Toi([,/]|\s)
# (/|\s)Topspeed([,/]|\s)
# (/|\s)TPU([,/]|\s)
# (/|\s)Trac([,/]|\s)
# (/|\s)TTM([,/]|\s)
# (/|\s)T\-SQL([,/]|\s)
# (/|\s)Transcript([,/]|\s)
# (/|\s)TTCN([,/]|\s)
# (/|\s)Turing([,/]|\s)
# (/|\s)TUTOR([,/]|\s)
# (/|\s)TXL([,/]|\s)
# (/|\s)TypeScript([,/]|\s)
# (/|\s)Tynker([,/]|\s)
# (/|\s)Ubercode([,/]|\s)
# (/|\s)UCSD\ Pascal([,/]|\s)
# (/|\s)Umple([,/]|\s)
# (/|\s)Unicon([,/]|\s)
# (/|\s)Uniface([,/]|\s)
# (/|\s)UNITY([,/]|\s)
# (/|\s)Unix\ shell([,/]|\s)
# (/|\s)UnrealScript([,/]|\s)
# (/|\s)Vala([,/]|\s)
# (/|\s)Verilog([,/]|\s)
# (/|\s)VHDL([,/]|\s)
# (/|\s)Vim\ script([,/]|\s)
# (/|\s)Viper([,/]|\s)
# (/|\s)Visual\ DataFlex([,/]|\s)
# (/|\s)Visual\ DialogScript([,/]|\s)
# (/|\s)Visual\ FoxPro([,/]|\s)
# (/|\s)Visual\ J\+\+([,/]|\s)
# (/|\s)Visual\ LISP([,/]|\s)
# (/|\s)Visual\ Objects([,/]|\s)
# (/|\s)Visual\ Prolog([,/]|\s)
# (/|\s)WATFIV,\ WATFOR([,/]|\s)
# (/|\s)WebAssembly([,/]|\s)
# (/|\s)WebDNA([,/]|\s)
# (/|\s)Whiley([,/]|\s)
# (/|\s)Winbatch([,/]|\s)
# (/|\s)Wolfram\ Language([,/]|\s)
# (/|\s)Wyvern([,/]|\s)
# (/|\s)X\+\+([,/]|\s)
# (/|\s)X10([,/]|\s)
# (/|\s)xBase([,/]|\s)
# (/|\s)xBase\+\+([,/]|\s)
# (/|\s)XBL([,/]|\s)
# (/|\s)XC([,/]|\s)
# (/|\s)xHarbour([,/]|\s)
# (/|\s)XL([,/]|\s)
# (/|\s)Xojo([,/]|\s)
# (/|\s)XOTcl([,/]|\s)
# (/|\s)Xod([,/]|\s)
# (/|\s)XPL([,/]|\s)
# (/|\s)XPL0([,/]|\s)
# (/|\s)XQuery([,/]|\s)
# (/|\s)XSB([,/]|\s)
# (/|\s)XSharp([,/]|\s)
# (/|\s)XSLT([,/]|\s)
# (/|\s)Xtend([,/]|\s)
# (/|\s)Yorick([,/]|\s)
# (/|\s)YQL([,/]|\s)
# (/|\s)Yoix([,/]|\s)
# (/|\s)YUI([,/]|\s)
# (/|\s)Z\ notation([,/]|\s)
# (/|\s)Zebra,\ ZPL,\ ZPL2([,/]|\s)
# (/|\s)Zeno([,/]|\s)
# (/|\s)ZetaLisp([,/]|\s)
# (/|\s)Zig([,/]|\s)
# (/|\s)ZOPL([,/]|\s)
# (/|\s)ZPL([,/]|\s)
# (/|\s)Z\+\+([,/]|\s)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-87a4d5497c54> in <module>
#      14             if re.search(exp, j, re.IGNORECASE):
#      15                 sub_count_df["count"].loc[i] += 1
# ---> 16     sub_count_df.to_csv(f"data/subsections/{sub}_lang_count.csv")
#
# ~\anaconda3\envs\scraper\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3400             doublequote=doublequote,
#    3401             escapechar=escapechar,
# -> 3402             storage_options=storage_options,
#    3403         )
#    3404
#
# ~\anaconda3\envs\scraper\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\envs\scraper\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~\anaconda3\envs\scraper\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 encoding=ioargs.encoding,
#     646                 errors=errors,
# --> 647                 newline="",
#     648             )
#     649         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/subsections/Business/Systems Analysts_lang_count.csv'

# %%
# Out:
# '\'

# %%
exp
# Out:
# '(/|\\s)\\A\\.\\N\\E\\T([,/]|\\s)'

# %%
lang
# Out:
# '\\\\Z\\\\+\\\\+'

# %%
count_df.index
# Out:
# RangeIndex(start=0, stop=685, step=1)

# %%
count_df
# Out:
#            lang  count
# 0        A.NET       0
# 1    A-0 System      0
# 2           A+       6
# 3          ABAP      4
# 4           ABC      0
# ..          ...    ...
# 680    ZetaLisp      0
# 681         Zig      0
# 682        ZOPL      0
# 683         ZPL      0
# 684         Z++      0
#
# [685 rows x 2 columns]

# %%
lang = "".join(list(map(lambda o: "\\"+o , list(count_df["lang"].loc[i].strip())))
# Out:
#   File "<ipython-input-62-a8f60d78b4e5>", line 1
#     lang = "".join(list(map(lambda o: "\\"+o , list(count_df["lang"].loc[i].strip())))
#                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
lang
# Out:
# '\\\\Z\\\\+\\\\+'

# %%
list(count_df["lang"].loc[0].strip())
# Out:
# ['A', '.', 'N', 'E', 'T']

# %%
exp[8]
# Out:
# '+'

# %%
exp
# Out:
# '(/|\\s)\\\\Z\\\\+\\\\+([,/]|\\s)'

# %%
lang
# Out:
# '\\A+'

# %%
list(lang)
# Out:
# ['\\', 'A', '+']
